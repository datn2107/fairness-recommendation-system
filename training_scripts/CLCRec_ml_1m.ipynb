# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install torch_geometric
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 12.7 MB/s eta 0:00:00
# ...

# %%
# !git clone https://github.com/datn2107/CLCRec.git
# Out:
# Cloning into 'CLCRec'...
# remote: Enumerating objects: 303, done.
# remote: Counting objects: 100% (222/222), done.
# remote: Compressing objects: 100% (106/106), done.
# remote: Total 303 (delta 147), reused 190 (delta 115), pack-reused 81
# Receiving objects: 100% (303/303), 40.67 MiB | 12.02 MiB/s, done.
# Resolving deltas: 100% (171/171), done.

# %% [markdown]
# # Training

# %%
SAVE_PATH = "/content/drive/MyDrive/Capstone/Dataset"
SEED = 2107

# %%
# %cd CLCRec
# Out:
# /content/CLCRec

# %%
# !git config pull.rebase true

# %%
# !git reset --hard
# !git pull
# Out:
# HEAD is now at e8d06c1 Convert GPU to CPU
# Already up to date.

# %%
DATASET = "ml-1m"

# %%
# !rm -rf $SAVE_PATH/$DATASET/result/CLCRec

# %%
# !python3 main.py --seed $SEED \
                 --data-path $SAVE_PATH/$DATASET \
                 --result-path $SAVE_PATH/$DATASET/result/CLCRec \
                 --has-t \
                 --lr 0.0001 \
                 --lr-lambda 0.5 \
                 --reg-weight 0.01 \
                 --temp-value 1.0 \
                 --num-neg 128 \
                 --num-sample 0.5 \
                 --top-k 10 \
                 --batch-size 8192 \
                 --num-epoch 1000 \
                 --early-stop 10
# Out:
# 2024-05-14 05:17:40.892264: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-14 05:17:40.892320: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-14 05:17:40.893686: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-05-14 05:17:40.901018: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
from google.colab import runtime
runtime.unassign()

# %%
DATASET = "Office_Products_Filtered"

# %%
# !rm -rf $SAVE_PATH/$DATASET/result/CLCRec

# %%
# !python3 main.py --seed $SEED \
                 --data-path $SAVE_PATH/$DATASET \
                 --result-path $SAVE_PATH/$DATASET/result/CLCRec_lrl05 \
                 --has-t \
                 --lr 0.00015 \
                 --lr-lambda 0.5 \
                 --reg-weight 0.01 \
                 --temp-value 1.0 \
                 --num-neg 512 \
                 --num-sample 0.5 \
                 --top-k 10 \
                 --batch-size 1024 \
                 --num-epoch 1000 \
                 --early-stop 10 \
                 --step 1024
# Out:
# 2024-04-24 04:27:49.197171: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-24 04:27:49.197231: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-24 04:27:49.199158: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-24 04:27:49.210170: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
DATASET = "Video_Games_Filtered"

# %%
# !rm -rf $SAVE_PATH/$DATASET/result/CLCRec

# %%
# !python3 main.py --seed $SEED \
                 --data-path $SAVE_PATH/$DATASET \
                 --result-path $SAVE_PATH/$DATASET/result/CLCRec \
                 --has-t \
                 --lr 0.00015 \
                 --lr-lambda 0.8 \
                 --reg-weight 0.01 \
                 --temp-value 1.0 \
                 --num-neg 512 \
                 --num-sample 0.5 \
                 --top-k 10 \
                 --batch-size 2048 \
                 --num-epoch 1000 \
                 --early-stop 10 \
                 --step 512
# Out:
# 2024-04-24 07:31:51.681315: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-24 07:31:51.681366: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-24 07:31:51.682894: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-24 07:31:51.690957: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...
