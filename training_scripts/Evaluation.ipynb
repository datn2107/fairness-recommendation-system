# %%
# !git clone https://github.com/datn2107/fairness-recommendation-system.git
# !python3 -m pip install -r fairness-recommendation-system/requirements.txt
# Out:
# Cloning into 'fairness-recommendation-system'...
# remote: Enumerating objects: 217, done.
# remote: Counting objects: 100% (67/67), done.
# remote: Compressing objects: 100% (41/41), done.
# remote: Total 217 (delta 41), reused 51 (delta 26), pack-reused 150
# Receiving objects: 100% (217/217), 6.51 MiB | 15.26 MiB/s, done.
# Resolving deltas: 100% (122/122), done.
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.3/15.3 MB 50.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.7/26.7 MB 14.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 441.8/441.8 kB 5.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.7/133.7 kB 6.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 309.2/309.2 kB 3.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
#     Uninstalling protobuf-3.20.3:
#       Successfully uninstalled protobuf-3.20.3
#   Attempting uninstall: cffi
# ...

# %%
# !mkdir /content/fairness-recommendation-system/dataset

# %%
SAVE_PATH = "/content/drive/MyDrive/Capstone/Dataset"
DATASET_PATH = "/content/fairness-recommendation-system/dataset"

# %% [markdown]
# # Get data from drive

# %%
import os
import numpy as np

# %%
DATASET = "Office_Products_Small"
DATASET = "Video_Games_Small"
DATASET = "ml-1m"
DATASET = "Video_Games"
DATASET = "Office_Products"
CLC_RESULT_VERSION = "CLCRec"
CCFC_RESULT_VERSION = "CCFCRec"

# %%
# !mkdir {DATASET_PATH}/{DATASET}
# Out:
# mkdir: cannot create directory ‘/content/fairness-recommendation-system/dataset/Office_Products’: File exists

# %%
# !cp {SAVE_PATH}/{DATASET}/test_cold_items.npy {DATASET_PATH}/{DATASET}
# !cp {SAVE_PATH}/{DATASET}/test_cold_interactions_provider_formated.npy {DATASET_PATH}/{DATASET}

# %%
# !cp {SAVE_PATH}/{DATASET}/result/{CLC_RESULT_VERSION}/clcrec_result_formated.npy {DATASET_PATH}/{DATASET}/clcrec_result.npy
# !cp {SAVE_PATH}/{DATASET}/result/{CCFC_RESULT_VERSION}/best_model_ratings.npy {DATASET_PATH}/{DATASET}/ccfcrec_result.npy

# %%
for model_name in ["clcrec", "ccfcrec"]:
    # !mv {SAVE_PATH}/{DATASET}/result/{model_name}_UMMf_reranked_result_binary.npy {SAVE_PATH}/{DATASET}/result/{model_name}_UMMF_reranked_result_binary.npy
    for model_type in ["MIP", "PDLP", "UMMF"]:
        model_filename = model_name + "_" + model_type + "_reranked_result_binary.npy"
        # !cp {SAVE_PATH}/{DATASET}/result/{model_filename} {DATASET_PATH}/{DATASET}
# Out:
# mv: cannot stat '/content/drive/MyDrive/Capstone/Dataset/Office_Products/result/clcrec_UMMf_reranked_result_binary.npy': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/Capstone/Dataset/Office_Products/result/clcrec_MIP_reranked_result_binary.npy': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/Capstone/Dataset/Office_Products/result/clcrec_PDLP_reranked_result_binary.npy': No such file or directory
# mv: cannot stat '/content/drive/MyDrive/Capstone/Dataset/Office_Products/result/ccfcrec_UMMf_reranked_result_binary.npy': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/Capstone/Dataset/Office_Products/result/ccfcrec_MIP_reranked_result_binary.npy': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/Capstone/Dataset/Office_Products/result/ccfcrec_PDLP_reranked_result_binary.npy': No such file or directory

# %% [markdown]
# # Evaluation

# %%
# %cd fairness-recommendation-system
# Out:
# [Errno 2] No such file or directory: 'fairness-recommendation-system'
# /content/fairness-recommendation-system

# %%
# !git config pull.rebase true

# %%
# !git reset --hard
# !git pull
# Out:
# HEAD is now at b6f5254 Update evaluation
# Already up to date.

# %%
# !python3 evaluation.py --dataset-dir /content/fairness-recommendation-system/dataset/{DATASET} \
                       --save-dir {SAVE_PATH}/{DATASET}/result \
                       --methods UMMF
# Out:
# (CVXPY) May 26 09:10:03 AM: Encountered unexpected exception importing solver GLOP:
# RuntimeError('Unrecognized new version of ortools (9.10.4067). Expected < 9.5.0.Please open a feature request on cvxpy to enable support for this version.')
# (CVXPY) May 26 09:10:03 AM: Encountered unexpected exception importing solver PDLP:
# RuntimeError('Unrecognized new version of ortools (9.10.4067). Expected < 9.5.0.Please open a feature request on cvxpy to enable support for this version.')
#    precision    recall      ndcg       rrq  ...   u_pf_10   u_pf_15  time         model
# 0   0.049488  0.049488  0.009927  1.000000  ...  0.544353  0.405540    -1        clcrec
# 0   0.017675  0.017675  0.003430  0.994707  ...  1.031237  0.802357    -1   clcrec_UMMF
# 0   0.046475  0.046475  0.008781  1.000000  ...  1.065579  0.826902    -1       ccfcrec
# 0   0.043433  0.043433  0.008167  0.999495  ...  1.078647  0.840183    -1  ccfcrec_UMMF
#
# [4 rows x 20 columns]

# %%
# !python3 evaluation.py --dataset-dir /content/fairness-recommendation-system/dataset/{DATASET} \
                       --save-dir {SAVE_PATH}/{DATASET}/result \
                       --methods UMMF \
                       --top-k 10
# Out:
# (CVXPY) May 26 07:48:22 AM: Encountered unexpected exception importing solver GLOP:
# RuntimeError('Unrecognized new version of ortools (9.10.4067). Expected < 9.5.0.Please open a feature request on cvxpy to enable support for this version.')
# (CVXPY) May 26 07:48:22 AM: Encountered unexpected exception importing solver PDLP:
# RuntimeError('Unrecognized new version of ortools (9.10.4067). Expected < 9.5.0.Please open a feature request on cvxpy to enable support for this version.')
#    precision    recall      ndcg       rrq  ...   u_pf_10   u_pf_15  time         model
# 0   0.001998  0.001998  0.000561  1.000000  ...  0.935195  0.692383    -1        clcrec
# 0   0.007742  0.007742  0.000720  0.994683  ...  3.093711  2.407070    -1   clcrec_UMMF
# 0   0.002784  0.002781  0.000771  1.000000  ...  2.085569  1.823900    -1       ccfcrec
# 0   0.007954  0.007946  0.000763  0.999900  ...  3.235942  2.520548    -1  ccfcrec_UMMF
#
# [4 rows x 20 columns]

# %%
# !python3 evaluation.py --dataset-dir /content/fairness-recommendation-system/dataset/{DATASET} \
                       --save-dir {SAVE_PATH}/{DATASET}/result
# Out:
# (CVXPY) May 26 07:24:37 AM: Encountered unexpected exception importing solver GLOP:
# RuntimeError('Unrecognized new version of ortools (9.10.4067). Expected < 9.5.0.Please open a feature request on cvxpy to enable support for this version.')
# (CVXPY) May 26 07:24:37 AM: Encountered unexpected exception importing solver PDLP:
# RuntimeError('Unrecognized new version of ortools (9.10.4067). Expected < 9.5.0.Please open a feature request on cvxpy to enable support for this version.')
#    precision    recall      ndcg       rrq  ...   u_pf_10   u_pf_15  time         model
# 0   0.247326  0.193930  0.203990  1.000000  ...  0.723848  0.449395    -1        clcrec
# 0   0.060377  0.042915  0.051672  0.042919  ...  2.880305  1.920203    -1   clcrec_PDLP
# 0   0.246384  0.193012  0.203451  0.999982  ...  0.749252  0.469651    -1    clcrec_MIP
# 0   0.142688  0.101031  0.125621  0.973820  ...  1.588763  1.212798    -1   clcrec_UMMF
# ...

# %%
# !python3 evaluation.py --dataset-dir /content/fairness-recommendation-system/dataset/{DATASET} \
                       --save-dir {SAVE_PATH}/{DATASET}/result \
                       --methods UMMF
# Out:
# (CVXPY) May 25 07:02:25 PM: Encountered unexpected exception importing solver GLOP:
# RuntimeError('Unrecognized new version of ortools (9.10.4067). Expected < 9.5.0.Please open a feature request on cvxpy to enable support for this version.')
# (CVXPY) May 25 07:02:25 PM: Encountered unexpected exception importing solver PDLP:
# RuntimeError('Unrecognized new version of ortools (9.10.4067). Expected < 9.5.0.Please open a feature request on cvxpy to enable support for this version.')
#    precision    recall      ndcg       rrq  ...   u_pf_10   u_pf_15  time         model
# 0   0.066986  0.066903  0.025929  1.000000  ...  0.165960  0.135827    -1        clcrec
# 0   0.048272  0.048182  0.019452  0.994692  ...  0.322145  0.246875    -1   clcrec_UMMF
# 0   0.035215  0.035158  0.013730  1.000000  ...  0.524131  0.378649    -1       ccfcrec
# 0   0.033253  0.033210  0.013107  0.999502  ...  0.527456  0.380944    -1  ccfcrec_UMMF
#
# [4 rows x 20 columns]

# %%
# !python3 evaluation.py --dataset-dir /content/fairness-recommendation-system/dataset/{DATASET} \
                       --save-dir {SAVE_PATH}/{DATASET}/result
# Out:
# (CVXPY) May 25 06:55:18 PM: Encountered unexpected exception importing solver GLOP:
# RuntimeError('Unrecognized new version of ortools (9.10.4067). Expected < 9.5.0.Please open a feature request on cvxpy to enable support for this version.')
# (CVXPY) May 25 06:55:18 PM: Encountered unexpected exception importing solver PDLP:
# RuntimeError('Unrecognized new version of ortools (9.10.4067). Expected < 9.5.0.Please open a feature request on cvxpy to enable support for this version.')
#    precision    recall      ndcg       rrq  ...   u_pf_10   u_pf_15  time         model
# 0   0.066986  0.066903  0.025929  1.000000  ...  0.165960  0.135827    -1        clcrec
# 0   0.007502  0.007481  0.002908  0.007495  ...  0.669742  0.446495    -1   clcrec_PDLP
# 0   0.066389  0.066307  0.025816  0.999902  ...  0.243342  0.192503    -1    clcrec_MIP
# 0   0.048272  0.048182  0.019452  0.994692  ...  0.322145  0.246875    -1   clcrec_UMMF
# ...

# %%
# !python3 evaluation.py --dataset-dir /content/fairness-recommendation-system/dataset/Video_Games \
                       --save-dir {SAVE_PATH}/{DATASET}/result
# Out:
# (CVXPY) May 25 06:47:31 PM: Encountered unexpected exception importing solver GLOP:
# RuntimeError('Unrecognized new version of ortools (9.10.4067). Expected < 9.5.0.Please open a feature request on cvxpy to enable support for this version.')
# (CVXPY) May 25 06:47:31 PM: Encountered unexpected exception importing solver PDLP:
# RuntimeError('Unrecognized new version of ortools (9.10.4067). Expected < 9.5.0.Please open a feature request on cvxpy to enable support for this version.')
#    precision    recall      ndcg       rrq  ...   u_pf_10   u_pf_15  time         model
# 0   0.066986  0.066903  0.025929  1.000000  ...  0.165960  0.135827    -1        clcrec
# 0   0.007502  0.007481  0.002908  0.007495  ...  0.669742  0.446495    -1   clcrec_PDLP
# 0   0.066389  0.066307  0.025816  0.999902  ...  0.243342  0.192503    -1    clcrec_MIP
# 0   0.048272  0.048182  0.019452  0.994692  ...  0.322145  0.246875    -1   clcrec_UMMF
# ...

# %%
# !python3 evaluation.py --dataset-dir /content/fairness-recommendation-system/dataset/Video_Games \
                       --save-dir {SAVE_PATH}/{DATASET}/result
# Out:
# (CVXPY) May 25 06:40:43 PM: Encountered unexpected exception importing solver GLOP:
# RuntimeError('Unrecognized new version of ortools (9.10.4067). Expected < 9.5.0.Please open a feature request on cvxpy to enable support for this version.')
# (CVXPY) May 25 06:40:43 PM: Encountered unexpected exception importing solver PDLP:
# RuntimeError('Unrecognized new version of ortools (9.10.4067). Expected < 9.5.0.Please open a feature request on cvxpy to enable support for this version.')
#    precision    recall      ndcg       rrq  ...   u_pf_10   u_pf_15  time         model
# 0   0.066986  0.066903  0.025929  1.000000  ...  0.165960  0.135827    -1        clcrec
# 0   0.007502  0.007481  0.002908  0.007495  ...  0.669742  0.446495    -1   clcrec_PDLP
# 0   0.066389  0.066307  0.025816  0.999902  ...  0.243342  0.192503    -1    clcrec_MIP
# 0   0.048272  0.048182  0.019452  0.994692  ...  0.322145  0.246875    -1   clcrec_UMMF
# ...
