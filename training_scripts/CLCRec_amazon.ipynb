# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/datn2107/CLCRec.git
# Out:
# Cloning into 'CLCRec'...
# remote: Enumerating objects: 306, done.
# remote: Counting objects: 100% (225/225), done.
# remote: Compressing objects: 100% (107/107), done.
# remote: Total 306 (delta 149), reused 193 (delta 117), pack-reused 81
# Receiving objects: 100% (306/306), 40.67 MiB | 32.24 MiB/s, done.
# Resolving deltas: 100% (173/173), done.

# %% [markdown]
# # Training

# %%
SAVE_PATH = "/content/drive/MyDrive/Capstone/Dataset"
SEED = 2107

# %%
# %cd CLCRec
# Out:
# /content/CLCRec

# %%
# !git config pull.rebase true

# %%
# !git reset --hard
# !git pull
# Out:
# HEAD is now at f5d4812 Ignore the timestamp in dataset
# Already up to date.

# %%
DATASET = "Office_Products"

# %%
# !rm -rf $SAVE_PATH/$DATASET/result/CLCRec

# %%
# !python3 main.py --seed $SEED \
                 --data-path $SAVE_PATH/$DATASET \
                 --result-path $SAVE_PATH/$DATASET/result/CLCRec \
                 --has-t \
                 --lr 0.00005 \
                 --lr-lambda 0.7 \
                 --reg-weight 0.01 \
                 --temp-value 1.0 \
                 --num-neg 512 \
                 --num-sample 0.5 \
                 --top-k 10 \
                 --batch-size 1024 \
                 --num-epoch 1000 \
                 --early-stop 10 \
                 --step 1024 \
                 --has-oh
# Out:
# 2024-05-21 18:30:51.269659: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-21 18:30:51.269710: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-21 18:30:51.271574: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-05-21 18:30:51.279319: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-05-21 18:30:52.741463: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /content/drive/MyDrive/Capstone/Dataset/Office_Products
# Data loading ...
# Data has been loaded.
# Start training epoch 0...
# Now, training start at epoch 0...
#   0% 0/45575 [00:00<?, ?it/s]/usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# 46080it [00:45, 1018.17it/s]
# ----------------- loss:6.240362432267931  model_loss:6.241355313195123 contrastive_loss:6.239321178860134 reg_loss:0.001041259463979966 --------------
# train/ start...
# ---------------------------------0-th Precition:0.0012 Recall:0.0009 NDCG:0.0055---------------------------------
# val/cold_ start...
# ---------------------------------0-th Precition:0.0032 Recall:0.0032 NDCG:0.0040---------------------------------
# test/cold_ start...
# ---------------------------------0-th Precition:0.0039 Recall:0.0039 NDCG:0.0061---------------------------------
# Save best model as /content/drive/MyDrive/Capstone/Dataset/Office_Products/result/CLCRec/model_lr_1e-05_lrl_0.7_reg_0.01_num_neg_512_tmp_1.0.pt with recall 0.003859964859373493
# Start training epoch 1...
# Now, training start at epoch 1...
# 46080it [00:44, 1043.83it/s]
# ----------------- loss:6.23608348634508  model_loss:6.241280746459961 contrastive_loss:6.235079871283637 reg_loss:0.0010036143267320263 --------------
# train/ start...
# ---------------------------------1-th Precition:0.0014 Recall:0.0010 NDCG:0.0063---------------------------------
# val/cold_ start...
# ---------------------------------1-th Precition:0.0031 Recall:0.0031 NDCG:0.0040---------------------------------
# test/cold_ start...
# ---------------------------------1-th Precition:0.0038 Recall:0.0038 NDCG:0.0060---------------------------------
# Start training epoch 2...
# Now, training start at epoch 2...
# 46080it [00:45, 1004.31it/s]
# ----------------- loss:6.231499195098877  model_loss:6.2412453757392035 contrastive_loss:6.230531628926595 reg_loss:0.0009675940899695787 --------------
# train/ start...
# ---------------------------------2-th Precition:0.0015 Recall:0.0011 NDCG:0.0068---------------------------------
# val/cold_ start...
# ---------------------------------2-th Precition:0.0030 Recall:0.0030 NDCG:0.0040---------------------------------
# test/cold_ start...
# ---------------------------------2-th Precition:0.0038 Recall:0.0038 NDCG:0.0061---------------------------------
# Start training epoch 3...
# Now, training start at epoch 3...
# 46080it [00:44, 1026.72it/s]
# ----------------- loss:6.226249112023248  model_loss:6.24121043947008 contrastive_loss:6.225316068861219 reg_loss:0.0009330577320522732 --------------
# train/ start...
# ---------------------------------3-th Precition:0.0016 Recall:0.0012 NDCG:0.0073---------------------------------
# val/cold_ start...
# ---------------------------------3-th Precition:0.0031 Recall:0.0031 NDCG:0.0041---------------------------------
# test/cold_ start...
# ---------------------------------3-th Precition:0.0045 Recall:0.0044 NDCG:0.0069---------------------------------
# Save best model as /content/drive/MyDrive/Capstone/Dataset/Office_Products/result/CLCRec/model_lr_1e-05_lrl_0.7_reg_0.01_num_neg_512_tmp_1.0.pt with recall 0.004443938839267048
# Start training epoch 4...
# Now, training start at epoch 4...
# 46080it [00:44, 1041.04it/s]
# ----------------- loss:6.219888994428847  model_loss:6.241180843777126 contrastive_loss:6.218989086151123 reg_loss:0.0008999284486182862 --------------
# train/ start...
# ---------------------------------4-th Precition:0.0018 Recall:0.0013 NDCG:0.0082---------------------------------
# val/cold_ start...
# ---------------------------------4-th Precition:0.0033 Recall:0.0033 NDCG:0.0044---------------------------------
# test/cold_ start...
# ---------------------------------4-th Precition:0.0045 Recall:0.0044 NDCG:0.0067---------------------------------
# Save best model as /content/drive/MyDrive/Capstone/Dataset/Office_Products/result/CLCRec/model_lr_1e-05_lrl_0.7_reg_0.01_num_neg_512_tmp_1.0.pt with recall 0.004449218893334801
# Start training epoch 5...
# Now, training start at epoch 5...
# 46080it [00:45, 1017.78it/s]
# ----------------- loss:6.211681026882595  model_loss:6.241152297125923 contrastive_loss:6.210812844170464 reg_loss:0.0008681671642180946 --------------
# train/ start...
# ---------------------------------5-th Precition:0.0022 Recall:0.0015 NDCG:0.0096---------------------------------
# val/cold_ start...
# ---------------------------------5-th Precition:0.0038 Recall:0.0038 NDCG:0.0049---------------------------------
# test/cold_ start...
# ---------------------------------5-th Precition:0.0045 Recall:0.0045 NDCG:0.0066---------------------------------
# Save best model as /content/drive/MyDrive/Capstone/Dataset/Office_Products/result/CLCRec/model_lr_1e-05_lrl_0.7_reg_0.01_num_neg_512_tmp_1.0.pt with recall 0.0045091768406375155
# Start training epoch 6...
# Now, training start at epoch 6...
# 46080it [00:44, 1028.43it/s]
# ----------------- loss:6.200346522861057  model_loss:6.241112030877007 contrastive_loss:6.199508804745144 reg_loss:0.0008377304391211105 --------------
# train/ start...
# ---------------------------------6-th Precition:0.0027 Recall:0.0019 NDCG:0.0116---------------------------------
# val/cold_ start...
# ---------------------------------6-th Precition:0.0043 Recall:0.0043 NDCG:0.0058---------------------------------
# test/cold_ start...
# ---------------------------------6-th Precition:0.0041 Recall:0.0041 NDCG:0.0068---------------------------------
# Start training epoch 7...
# Now, training start at epoch 7...
# 46080it [00:43, 1053.34it/s]
# ----------------- loss:6.183433850606282  model_loss:6.241083823310005 contrastive_loss:6.182625357309977 reg_loss:0.0008085111608832246 --------------
# train/ start...
# ---------------------------------7-th Precition:0.0031 Recall:0.0022 NDCG:0.0137---------------------------------
# val/cold_ start...
# ---------------------------------7-th Precition:0.0055 Recall:0.0055 NDCG:0.0074---------------------------------
# test/cold_ start...
# ---------------------------------7-th Precition:0.0042 Recall:0.0042 NDCG:0.0072---------------------------------
# Start training epoch 8...
# Now, training start at epoch 8...
# 46080it [00:43, 1052.00it/s]
# ----------------- loss:6.155479388766818  model_loss:6.241060045030382 contrastive_loss:6.154698732164171 reg_loss:0.0007806484936736524 --------------
# train/ start...
# ---------------------------------8-th Precition:0.0034 Recall:0.0024 NDCG:0.0154---------------------------------
# val/cold_ start...
# ---------------------------------8-th Precition:0.0068 Recall:0.0067 NDCG:0.0091---------------------------------
# test/cold_ start...
# ---------------------------------8-th Precition:0.0043 Recall:0.0043 NDCG:0.0070---------------------------------
# Start training epoch 9...
# Now, training start at epoch 9...
# 46080it [00:43, 1052.44it/s]
# ----------------- loss:6.110600365532769  model_loss:6.241030820210775 contrastive_loss:6.109846252865261 reg_loss:0.0007540853758756486 --------------
# train/ start...
# ---------------------------------9-th Precition:0.0038 Recall:0.0026 NDCG:0.0173---------------------------------
# val/cold_ start...
# ---------------------------------9-th Precition:0.0062 Recall:0.0062 NDCG:0.0086---------------------------------
# test/cold_ start...
# ---------------------------------9-th Precition:0.0041 Recall:0.0041 NDCG:0.0072---------------------------------
# Start training epoch 10...
# Now, training start at epoch 10...
# 46080it [00:43, 1049.24it/s]
# ----------------- loss:6.062907261318631  model_loss:6.241007508171929 contrastive_loss:6.062178399827745 reg_loss:0.0007288744168666502 --------------
# train/ start...
# ---------------------------------10-th Precition:0.0042 Recall:0.0029 NDCG:0.0188---------------------------------
# val/cold_ start...
# ---------------------------------10-th Precition:0.0062 Recall:0.0062 NDCG:0.0088---------------------------------
# test/cold_ start...
# ---------------------------------10-th Precition:0.0041 Recall:0.0041 NDCG:0.0070---------------------------------
# Start training epoch 11...
# Now, training start at epoch 11...
# 46080it [00:43, 1051.88it/s]
# ----------------- loss:6.030639616648356  model_loss:6.240976916419135 contrastive_loss:6.029934649997287 reg_loss:0.0007049749010346002 --------------
# train/ start...
# ---------------------------------11-th Precition:0.0047 Recall:0.0032 NDCG:0.0205---------------------------------
# val/cold_ start...
# ---------------------------------11-th Precition:0.0059 Recall:0.0059 NDCG:0.0089---------------------------------
# test/cold_ start...
# ---------------------------------11-th Precition:0.0047 Recall:0.0047 NDCG:0.0076---------------------------------
# Save best model as /content/drive/MyDrive/Capstone/Dataset/Office_Products/result/CLCRec/model_lr_1e-05_lrl_0.7_reg_0.01_num_neg_512_tmp_1.0.pt with recall 0.004708186878500303
# Start training epoch 12...
# Now, training start at epoch 12...
# 46080it [00:43, 1058.42it/s]
# ----------------- loss:6.004987282223172  model_loss:6.2409558508131235 contrastive_loss:6.004305108388265 reg_loss:0.0006821935207376049 --------------
# train/ start...
# ---------------------------------12-th Precition:0.0052 Recall:0.0036 NDCG:0.0231---------------------------------
# val/cold_ start...
# ---------------------------------12-th Precition:0.0057 Recall:0.0057 NDCG:0.0088---------------------------------
# test/cold_ start...
# ---------------------------------12-th Precition:0.0053 Recall:0.0053 NDCG:0.0078---------------------------------
# Save best model as /content/drive/MyDrive/Capstone/Dataset/Office_Products/result/CLCRec/model_lr_1e-05_lrl_0.7_reg_0.01_num_neg_512_tmp_1.0.pt with recall 0.005304480984551948
# Start training epoch 13...
# Now, training start at epoch 13...
# 46080it [00:44, 1046.76it/s]
# ----------------- loss:5.982477739122179  model_loss:6.240933746761746 contrastive_loss:5.981817330254449 reg_loss:0.0006603919124851624 --------------
# train/ start...
# ---------------------------------13-th Precition:0.0056 Recall:0.0039 NDCG:0.0249---------------------------------
# val/cold_ start...
# ---------------------------------13-th Precition:0.0054 Recall:0.0054 NDCG:0.0085---------------------------------
# test/cold_ start...
# ---------------------------------13-th Precition:0.0060 Recall:0.0060 NDCG:0.0082---------------------------------
# Save best model as /content/drive/MyDrive/Capstone/Dataset/Office_Products/result/CLCRec/model_lr_1e-05_lrl_0.7_reg_0.01_num_neg_512_tmp_1.0.pt with recall 0.005982087923247
# Start training epoch 14...
# Now, training start at epoch 14...
# 46080it [00:43, 1048.41it/s]
# ----------------- loss:5.961869917975532  model_loss:6.2409107208251955 contrastive_loss:5.961230447557237 reg_loss:0.0006394774277901484 --------------
# train/ start...
# ---------------------------------14-th Precition:0.0059 Recall:0.0041 NDCG:0.0260---------------------------------
# val/cold_ start...
# ---------------------------------14-th Precition:0.0053 Recall:0.0053 NDCG:0.0082---------------------------------
# test/cold_ start...
# ---------------------------------14-th Precition:0.0060 Recall:0.0059 NDCG:0.0081---------------------------------
# Start training epoch 15...
# Now, training start at epoch 15...
# 46080it [00:44, 1045.96it/s]
# ----------------- loss:5.942878882090251  model_loss:6.2408923784891766 contrastive_loss:5.942259449428982 reg_loss:0.0006194419253410565 --------------
# train/ start...
# ---------------------------------15-th Precition:0.0064 Recall:0.0044 NDCG:0.0278---------------------------------
# val/cold_ start...
# ---------------------------------15-th Precition:0.0052 Recall:0.0052 NDCG:0.0083---------------------------------
# test/cold_ start...
# ---------------------------------15-th Precition:0.0060 Recall:0.0060 NDCG:0.0082---------------------------------
# Save best model as /content/drive/MyDrive/Capstone/Dataset/Office_Products/result/CLCRec/model_lr_1e-05_lrl_0.7_reg_0.01_num_neg_512_tmp_1.0.pt with recall 0.006023155010440639
# Start training epoch 16...
# Now, training start at epoch 16...
# 46080it [00:44, 1042.38it/s]
# ----------------- loss:5.924932034810384  model_loss:6.240870645311143 contrastive_loss:5.924331834581163 reg_loss:0.0006001818627636465 --------------
# train/ start...
# ---------------------------------16-th Precition:0.0065 Recall:0.0046 NDCG:0.0286---------------------------------
# val/cold_ start...
# ---------------------------------16-th Precition:0.0051 Recall:0.0051 NDCG:0.0080---------------------------------
# test/cold_ start...
# ---------------------------------16-th Precition:0.0063 Recall:0.0063 NDCG:0.0081---------------------------------
# Save best model as /content/drive/MyDrive/Capstone/Dataset/Office_Products/result/CLCRec/model_lr_1e-05_lrl_0.7_reg_0.01_num_neg_512_tmp_1.0.pt with recall 0.006252533359274931
# Start training epoch 17...
# Now, training start at epoch 17...
# 46080it [00:44, 1038.87it/s]
# ----------------- loss:5.907984892527263  model_loss:6.240851073794895 contrastive_loss:5.907403246561686 reg_loss:0.000581665449620535 --------------
# train/ start...
# ---------------------------------17-th Precition:0.0072 Recall:0.0051 NDCG:0.0308---------------------------------
# val/cold_ start...
# ---------------------------------17-th Precition:0.0054 Recall:0.0054 NDCG:0.0080---------------------------------
# test/cold_ start...
# ---------------------------------17-th Precition:0.0060 Recall:0.0060 NDCG:0.0081---------------------------------
# Start training epoch 18...
# Now, training start at epoch 18...
# 46080it [00:44, 1037.21it/s]
# ----------------- loss:5.892214510175917  model_loss:6.240834871927897 contrastive_loss:5.891650729709202 reg_loss:0.0005637785794937776 --------------
# train/ start...
# ---------------------------------18-th Precition:0.0074 Recall:0.0052 NDCG:0.0320---------------------------------
# val/cold_ start...
# ---------------------------------18-th Precition:0.0048 Recall:0.0048 NDCG:0.0075---------------------------------
# test/cold_ start...
# ---------------------------------18-th Precition:0.0062 Recall:0.0062 NDCG:0.0082---------------------------------
# Start training epoch 19...
# Now, training start at epoch 19...
# 46080it [00:44, 1044.04it/s]
# ----------------- loss:5.877038553025987  model_loss:6.240817589230008 contrastive_loss:5.876491991678874 reg_loss:0.0005465642264526751 --------------
# train/ start...
# ---------------------------------19-th Precition:0.0076 Recall:0.0053 NDCG:0.0329---------------------------------
# val/cold_ start...
# ---------------------------------19-th Precition:0.0052 Recall:0.0052 NDCG:0.0076---------------------------------
# test/cold_ start...
# ---------------------------------19-th Precition:0.0060 Recall:0.0060 NDCG:0.0081---------------------------------
# Start training epoch 20...
# Now, training start at epoch 20...
# 46080it [00:44, 1044.34it/s]
# ----------------- loss:5.862558417850071  model_loss:6.240798473358154 contrastive_loss:5.862028344472249 reg_loss:0.0005300349090248347 --------------
# train/ start...
# ---------------------------------20-th Precition:0.0078 Recall:0.0055 NDCG:0.0335---------------------------------
# val/cold_ start...
# ---------------------------------20-th Precition:0.0053 Recall:0.0053 NDCG:0.0078---------------------------------
# test/cold_ start...
# ---------------------------------20-th Precition:0.0060 Recall:0.0060 NDCG:0.0082---------------------------------
# Start training epoch 21...
# Now, training start at epoch 21...
# 46080it [00:43, 1052.28it/s]
# ----------------- loss:5.848482248518202  model_loss:6.24078270594279 contrastive_loss:5.8479681862725155 reg_loss:0.0005140886292792857 --------------
# train/ start...
# ---------------------------------21-th Precition:0.0079 Recall:0.0055 NDCG:0.0343---------------------------------
# val/cold_ start...
# ---------------------------------21-th Precition:0.0053 Recall:0.0053 NDCG:0.0078---------------------------------
# test/cold_ start...
# ---------------------------------21-th Precition:0.0060 Recall:0.0060 NDCG:0.0081---------------------------------
# Start training epoch 22...
# Now, training start at epoch 22...
# 46080it [00:43, 1047.45it/s]
# ----------------- loss:5.835076300303141  model_loss:6.240767161051433 contrastive_loss:5.8345775922139484 reg_loss:0.0004987042164430022 --------------
# train/ start...
# ---------------------------------22-th Precition:0.0079 Recall:0.0055 NDCG:0.0346---------------------------------
# val/cold_ start...
# ---------------------------------22-th Precition:0.0054 Recall:0.0054 NDCG:0.0081---------------------------------
# test/cold_ start...
# ---------------------------------22-th Precition:0.0062 Recall:0.0062 NDCG:0.0084---------------------------------
# Start training epoch 23...
# Now, training start at epoch 23...
# 46080it [00:43, 1058.50it/s]
# ----------------- loss:5.82253409491645  model_loss:6.240752771165636 contrastive_loss:5.82205024295383 reg_loss:0.0004838493536226451 --------------
# train/ start...
# ---------------------------------23-th Precition:0.0081 Recall:0.0055 NDCG:0.0354---------------------------------
# val/cold_ start...
# ---------------------------------23-th Precition:0.0054 Recall:0.0054 NDCG:0.0084---------------------------------
# test/cold_ start...
# ---------------------------------23-th Precition:0.0066 Recall:0.0066 NDCG:0.0088---------------------------------
# Save best model as /content/drive/MyDrive/Capstone/Dataset/Office_Products/result/CLCRec/model_lr_1e-05_lrl_0.7_reg_0.01_num_neg_512_tmp_1.0.pt with recall 0.006599043574206198
# Start training epoch 24...
# Now, training start at epoch 24...
# 46080it [00:43, 1047.96it/s]
# ----------------- loss:5.810050699445936  model_loss:6.2407374593946665 contrastive_loss:5.809581152598063 reg_loss:0.00046953007824615474 --------------
# train/ start...
# ---------------------------------24-th Precition:0.0082 Recall:0.0056 NDCG:0.0360---------------------------------
# val/cold_ start...
# ---------------------------------24-th Precition:0.0057 Recall:0.0057 NDCG:0.0081---------------------------------
# test/cold_ start...
# ---------------------------------24-th Precition:0.0070 Recall:0.0070 NDCG:0.0091---------------------------------
# Save best model as /content/drive/MyDrive/Capstone/Dataset/Office_Products/result/CLCRec/model_lr_1e-05_lrl_0.7_reg_0.01_num_neg_512_tmp_1.0.pt with recall 0.007020391888812939
# Start training epoch 25...
# Now, training start at epoch 25...
# 46080it [00:43, 1052.11it/s]
# ----------------- loss:5.798405244615343  model_loss:6.240723747677273 contrastive_loss:5.79794954723782 reg_loss:0.0004556808536613567 --------------
# train/ start...
# ---------------------------------25-th Precition:0.0084 Recall:0.0057 NDCG:0.0361---------------------------------
# val/cold_ start...
# ---------------------------------25-th Precition:0.0055 Recall:0.0055 NDCG:0.0082---------------------------------
# test/cold_ start...
# ---------------------------------25-th Precition:0.0067 Recall:0.0067 NDCG:0.0086---------------------------------
# Start training epoch 26...
# Now, training start at epoch 26...
# 46080it [00:43, 1054.92it/s]
# ----------------- loss:5.786980438232422  model_loss:6.240708541870117 contrastive_loss:5.786538049909804 reg_loss:0.0004423860835635828 --------------
# train/ start...
# ---------------------------------26-th Precition:0.0087 Recall:0.0059 NDCG:0.0366---------------------------------
# val/cold_ start...
# ---------------------------------26-th Precition:0.0055 Recall:0.0054 NDCG:0.0081---------------------------------
# test/cold_ start...
# ---------------------------------26-th Precition:0.0068 Recall:0.0068 NDCG:0.0087---------------------------------
# Start training epoch 27...
# Now, training start at epoch 27...
# 46080it [00:43, 1053.53it/s]
# ----------------- loss:5.77579844792684  model_loss:6.240695423550076 contrastive_loss:5.775368944803874 reg_loss:0.00042947086492656835 --------------
# train/ start...
# ---------------------------------27-th Precition:0.0087 Recall:0.0059 NDCG:0.0368---------------------------------
# val/cold_ start...
# ---------------------------------27-th Precition:0.0054 Recall:0.0054 NDCG:0.0080---------------------------------
# test/cold_ start...
# ---------------------------------27-th Precition:0.0069 Recall:0.0068 NDCG:0.0087---------------------------------
# Start training epoch 28...
# Now, training start at epoch 28...
# 46080it [00:43, 1048.92it/s]
# ----------------- loss:5.765248182084825  model_loss:6.240682125091553 contrastive_loss:5.764831161499023 reg_loss:0.0004170469066593796 --------------
# train/ start...
# ---------------------------------28-th Precition:0.0090 Recall:0.0061 NDCG:0.0373---------------------------------
# val/cold_ start...
# ---------------------------------28-th Precition:0.0058 Recall:0.0057 NDCG:0.0084---------------------------------
# test/cold_ start...
# ---------------------------------28-th Precition:0.0070 Recall:0.0069 NDCG:0.0089---------------------------------
# Start training epoch 29...
# Now, training start at epoch 29...
# 46080it [00:43, 1050.49it/s]
# ----------------- loss:5.754985343085395  model_loss:6.24067014058431 contrastive_loss:5.754580328199599 reg_loss:0.0004050277794400851 --------------
# train/ start...
# ---------------------------------29-th Precition:0.0091 Recall:0.0062 NDCG:0.0376---------------------------------
# val/cold_ start...
# ---------------------------------29-th Precition:0.0058 Recall:0.0058 NDCG:0.0086---------------------------------
# test/cold_ start...
# ---------------------------------29-th Precition:0.0074 Recall:0.0074 NDCG:0.0095---------------------------------
# Save best model as /content/drive/MyDrive/Capstone/Dataset/Office_Products/result/CLCRec/model_lr_1e-05_lrl_0.7_reg_0.01_num_neg_512_tmp_1.0.pt with recall 0.007357680675983454
# Start training epoch 30...
# Now, training start at epoch 30...
# 46080it [00:43, 1055.39it/s]
# ----------------- loss:5.7451025115119085  model_loss:6.240658166673448 contrastive_loss:5.744708993699816 reg_loss:0.00039346826961264016 --------------
# train/ start...
# ---------------------------------30-th Precition:0.0090 Recall:0.0061 NDCG:0.0370---------------------------------
# val/cold_ start...
# ---------------------------------30-th Precition:0.0063 Recall:0.0063 NDCG:0.0091---------------------------------
# test/cold_ start...
# ---------------------------------30-th Precition:0.0074 Recall:0.0074 NDCG:0.0097---------------------------------
# Save best model as /content/drive/MyDrive/Capstone/Dataset/Office_Products/result/CLCRec/model_lr_1e-05_lrl_0.7_reg_0.01_num_neg_512_tmp_1.0.pt with recall 0.007416817281542295
# Start training epoch 31...
# Now, training start at epoch 31...
# 46080it [00:43, 1054.39it/s]
# ----------------- loss:5.735433620876736  model_loss:6.240646860334608 contrastive_loss:5.735051367017958 reg_loss:0.00038225448030668 --------------
# train/ start...
# ---------------------------------31-th Precition:0.0090 Recall:0.0061 NDCG:0.0370---------------------------------
# val/cold_ start...
# ---------------------------------31-th Precition:0.0064 Recall:0.0064 NDCG:0.0093---------------------------------
# test/cold_ start...
# ---------------------------------31-th Precition:0.0072 Recall:0.0072 NDCG:0.0098---------------------------------
# Start training epoch 32...
# Now, training start at epoch 32...
# 46080it [00:43, 1059.28it/s]
# ----------------- loss:5.726165347629124  model_loss:6.2406353526645235 contrastive_loss:5.725793902079264 reg_loss:0.00037145256905609536 --------------
# train/ start...
# ---------------------------------32-th Precition:0.0093 Recall:0.0062 NDCG:0.0373---------------------------------
# val/cold_ start...
# ---------------------------------32-th Precition:0.0064 Recall:0.0064 NDCG:0.0095---------------------------------
# test/cold_ start...
# ---------------------------------32-th Precition:0.0074 Recall:0.0074 NDCG:0.0101---------------------------------
# Start training epoch 33...
# Now, training start at epoch 33...
# 46080it [00:43, 1048.67it/s]
# ----------------- loss:5.717245451609293  model_loss:6.240624978807237 contrastive_loss:5.71688445409139 reg_loss:0.0003609912612268494 --------------
# train/ start...
# ---------------------------------33-th Precition:0.0094 Recall:0.0064 NDCG:0.0379---------------------------------
# val/cold_ start...
# ---------------------------------33-th Precition:0.0061 Recall:0.0061 NDCG:0.0095---------------------------------
# test/cold_ start...
# ---------------------------------33-th Precition:0.0075 Recall:0.0075 NDCG:0.0102---------------------------------
# Save best model as /content/drive/MyDrive/Capstone/Dataset/Office_Products/result/CLCRec/model_lr_1e-05_lrl_0.7_reg_0.01_num_neg_512_tmp_1.0.pt with recall 0.007487335336980516
# Start training epoch 34...
# Now, training start at epoch 34...
# 46080it [00:43, 1051.17it/s]
# ----------------- loss:5.7084071901109485  model_loss:6.2406153361002605 contrastive_loss:5.708056269751655 reg_loss:0.00035091968149774603 --------------
# train/ start...
# ---------------------------------34-th Precition:0.0095 Recall:0.0064 NDCG:0.0383---------------------------------
# val/cold_ start...
# ---------------------------------34-th Precition:0.0065 Recall:0.0065 NDCG:0.0096---------------------------------
# test/cold_ start...
# ---------------------------------34-th Precition:0.0079 Recall:0.0078 NDCG:0.0105---------------------------------
# Save best model as /content/drive/MyDrive/Capstone/Dataset/Office_Products/result/CLCRec/model_lr_1e-05_lrl_0.7_reg_0.01_num_neg_512_tmp_1.0.pt with recall 0.007834762894638707
# Start training epoch 35...
# Now, training start at epoch 35...
# 46080it [00:43, 1051.50it/s]
# ----------------- loss:5.699798170725504  model_loss:6.240604061550564 contrastive_loss:5.699457020229763 reg_loss:0.0003411867875709302 --------------
# train/ start...
# ---------------------------------35-th Precition:0.0097 Recall:0.0065 NDCG:0.0389---------------------------------
# val/cold_ start...
# ---------------------------------35-th Precition:0.0063 Recall:0.0063 NDCG:0.0097---------------------------------
# test/cold_ start...
# ---------------------------------35-th Precition:0.0080 Recall:0.0079 NDCG:0.0104---------------------------------
# Save best model as /content/drive/MyDrive/Capstone/Dataset/Office_Products/result/CLCRec/model_lr_1e-05_lrl_0.7_reg_0.01_num_neg_512_tmp_1.0.pt with recall 0.007942828001225397
# Start training epoch 36...
# Now, training start at epoch 36...
# 46080it [00:43, 1047.67it/s]
# ----------------- loss:5.691613652971056  model_loss:6.240595287746853 contrastive_loss:5.691281869676378 reg_loss:0.00033178765184452963 --------------
# train/ start...
# ---------------------------------36-th Precition:0.0096 Recall:0.0065 NDCG:0.0385---------------------------------
# val/cold_ start...
# ---------------------------------36-th Precition:0.0065 Recall:0.0065 NDCG:0.0098---------------------------------
# test/cold_ start...
# ---------------------------------36-th Precition:0.0082 Recall:0.0082 NDCG:0.0105---------------------------------
# Save best model as /content/drive/MyDrive/Capstone/Dataset/Office_Products/result/CLCRec/model_lr_1e-05_lrl_0.7_reg_0.01_num_neg_512_tmp_1.0.pt with recall 0.00817997176291085
# Start training epoch 37...
# Now, training start at epoch 37...
# 46080it [00:43, 1049.97it/s]
# ----------------- loss:5.683697181277805  model_loss:6.240585655636258 contrastive_loss:5.683374542660183 reg_loss:0.00032261380498918395 --------------
# train/ start...
# ---------------------------------37-th Precition:0.0096 Recall:0.0064 NDCG:0.0385---------------------------------
# val/cold_ start...
# ---------------------------------37-th Precition:0.0068 Recall:0.0068 NDCG:0.0099---------------------------------
# test/cold_ start...
# ---------------------------------37-th Precition:0.0084 Recall:0.0083 NDCG:0.0109---------------------------------
# Save best model as /content/drive/MyDrive/Capstone/Dataset/Office_Products/result/CLCRec/model_lr_1e-05_lrl_0.7_reg_0.01_num_neg_512_tmp_1.0.pt with recall 0.008345882795173154
# Start training epoch 38...
# Now, training start at epoch 38...
# 46080it [00:43, 1048.36it/s]
# ----------------- loss:5.675948736402724  model_loss:6.240577136145697 contrastive_loss:5.675634871588813 reg_loss:0.0003138546721958038 --------------
# train/ start...
# ---------------------------------38-th Precition:0.0098 Recall:0.0066 NDCG:0.0393---------------------------------
# val/cold_ start...
# ---------------------------------38-th Precition:0.0067 Recall:0.0067 NDCG:0.0097---------------------------------
# test/cold_ start...
# ---------------------------------38-th Precition:0.0084 Recall:0.0083 NDCG:0.0114---------------------------------
# Save best model as /content/drive/MyDrive/Capstone/Dataset/Office_Products/result/CLCRec/model_lr_1e-05_lrl_0.7_reg_0.01_num_neg_512_tmp_1.0.pt with recall 0.008347066807297437
# Start training epoch 39...
# Now, training start at epoch 39...
# 46080it [00:43, 1049.33it/s]
# ----------------- loss:5.668730195363363  model_loss:6.240568044450548 contrastive_loss:5.668424818250868 reg_loss:0.00030536237884209387 --------------
# train/ start...
# ---------------------------------39-th Precition:0.0099 Recall:0.0066 NDCG:0.0399---------------------------------
# val/cold_ start...
# ---------------------------------39-th Precition:0.0069 Recall:0.0069 NDCG:0.0099---------------------------------
# test/cold_ start...
# ---------------------------------39-th Precition:0.0086 Recall:0.0086 NDCG:0.0120---------------------------------
# Save best model as /content/drive/MyDrive/Capstone/Dataset/Office_Products/result/CLCRec/model_lr_1e-05_lrl_0.7_reg_0.01_num_neg_512_tmp_1.0.pt with recall 0.008599218722666384
# Start training epoch 40...
# Now, training start at epoch 40...
# 46080it [00:43, 1065.79it/s]
# ----------------- loss:5.661329735649956  model_loss:6.240560213724772 contrastive_loss:5.6610325707329645 reg_loss:0.00029716323220377994 --------------
# train/ start...
# ---------------------------------40-th Precition:0.0101 Recall:0.0067 NDCG:0.0402---------------------------------
# val/cold_ start...
# ---------------------------------40-th Precition:0.0068 Recall:0.0068 NDCG:0.0101---------------------------------
# test/cold_ start...
# ---------------------------------40-th Precition:0.0085 Recall:0.0085 NDCG:0.0122---------------------------------
# Start training epoch 41...
# Now, training start at epoch 41...
# 46080it [00:43, 1054.31it/s]
# ----------------- loss:5.654301537407769  model_loss:6.240552340613471 contrastive_loss:5.654012330373129 reg_loss:0.0002891998395272013 --------------
# train/ start...
# ---------------------------------41-th Precition:0.0099 Recall:0.0065 NDCG:0.0402---------------------------------
# val/cold_ start...
# ---------------------------------41-th Precition:0.0067 Recall:0.0067 NDCG:0.0101---------------------------------
# test/cold_ start...
# ---------------------------------41-th Precition:0.0084 Recall:0.0083 NDCG:0.0120---------------------------------
# Start training epoch 42...
# Now, training start at epoch 42...
# 46080it [00:44, 1045.22it/s]
# ----------------- loss:5.647730424669054  model_loss:6.2405446370442705 contrastive_loss:5.647448889414469 reg_loss:0.0002815218241367903 --------------
# train/ start...
# ---------------------------------42-th Precition:0.0100 Recall:0.0066 NDCG:0.0411---------------------------------
# val/cold_ start...
# ---------------------------------42-th Precition:0.0066 Recall:0.0066 NDCG:0.0096---------------------------------
# test/cold_ start...
# ---------------------------------42-th Precition:0.0083 Recall:0.0083 NDCG:0.0119---------------------------------
# Start training epoch 43...
# Now, training start at epoch 43...
# 46080it [00:46, 981.16it/s]
# ----------------- loss:5.641434690687391  model_loss:6.240536965264214 contrastive_loss:5.641160594092475 reg_loss:0.00027412962905752164 --------------
# train/ start...
# ---------------------------------43-th Precition:0.0101 Recall:0.0066 NDCG:0.0415---------------------------------
# val/cold_ start...
# ---------------------------------43-th Precition:0.0065 Recall:0.0064 NDCG:0.0094---------------------------------
# test/cold_ start...
# ---------------------------------43-th Precition:0.0084 Recall:0.0084 NDCG:0.0125---------------------------------
# Start training epoch 44...
# Now, training start at epoch 44...
# 46080it [00:44, 1039.86it/s]
# ----------------- loss:5.635139571295844  model_loss:6.240529961056179 contrastive_loss:5.634872627258301 reg_loss:0.00026697820155984826 --------------
# train/ start...
# ---------------------------------44-th Precition:0.0098 Recall:0.0065 NDCG:0.0403---------------------------------
# val/cold_ start...
# ---------------------------------44-th Precition:0.0066 Recall:0.0066 NDCG:0.0094---------------------------------
# test/cold_ start...
# ---------------------------------44-th Precition:0.0085 Recall:0.0085 NDCG:0.0127---------------------------------
# Start training epoch 45...
# Now, training start at epoch 45...
# 46080it [00:43, 1054.73it/s]
# ----------------- loss:5.62884767320421  model_loss:6.240523126390245 contrastive_loss:5.6285876168145075 reg_loss:0.0002600123782435225 --------------
# train/ start...
# ---------------------------------45-th Precition:0.0099 Recall:0.0065 NDCG:0.0403---------------------------------
# val/cold_ start...
# ---------------------------------45-th Precition:0.0068 Recall:0.0068 NDCG:0.0098---------------------------------
# test/cold_ start...
# ---------------------------------45-th Precition:0.0086 Recall:0.0086 NDCG:0.0132---------------------------------
# Start training epoch 46...
# Now, training start at epoch 46...
# 46080it [00:43, 1047.86it/s]
# ----------------- loss:5.623201211293538  model_loss:6.240516397688124 contrastive_loss:5.622947915395101 reg_loss:0.00025331256393757134 --------------
# train/ start...
# ---------------------------------46-th Precition:0.0098 Recall:0.0064 NDCG:0.0404---------------------------------
# val/cold_ start...
# ---------------------------------46-th Precition:0.0069 Recall:0.0068 NDCG:0.0098---------------------------------
# test/cold_ start...
# ---------------------------------46-th Precition:0.0085 Recall:0.0085 NDCG:0.0134---------------------------------
# Start training epoch 47...
# Now, training start at epoch 47...
# 46080it [00:44, 1024.55it/s]
# ----------------- loss:5.617860402001275  model_loss:6.240510092841254 contrastive_loss:5.617613559299045 reg_loss:0.00024682831588304703 --------------
# train/ start...
# ---------------------------------47-th Precition:0.0100 Recall:0.0065 NDCG:0.0410---------------------------------
# val/cold_ start...
# ---------------------------------47-th Precition:0.0069 Recall:0.0068 NDCG:0.0097---------------------------------
# test/cold_ start...
# ---------------------------------47-th Precition:0.0087 Recall:0.0086 NDCG:0.0134---------------------------------
# Save best model as /content/drive/MyDrive/Capstone/Dataset/Office_Products/result/CLCRec/model_lr_1e-05_lrl_0.7_reg_0.01_num_neg_512_tmp_1.0.pt with recall 0.008646456539714964
# Start training epoch 48...
# Now, training start at epoch 48...
# 46080it [00:45, 1010.14it/s]
# ----------------- loss:5.612210379706489  model_loss:6.240504211849636 contrastive_loss:5.6119698206583655 reg_loss:0.00024057308619376271 --------------
# train/ start...
# ---------------------------------48-th Precition:0.0100 Recall:0.0065 NDCG:0.0408---------------------------------
# val/cold_ start...
# ---------------------------------48-th Precition:0.0075 Recall:0.0075 NDCG:0.0099---------------------------------
# test/cold_ start...
# ---------------------------------48-th Precition:0.0087 Recall:0.0087 NDCG:0.0132---------------------------------
# Save best model as /content/drive/MyDrive/Capstone/Dataset/Office_Products/result/CLCRec/model_lr_1e-05_lrl_0.7_reg_0.01_num_neg_512_tmp_1.0.pt with recall 0.00866863276679953
# Start training epoch 49...
# Now, training start at epoch 49...
# 46080it [00:44, 1036.54it/s]
# ----------------- loss:5.607032828860813  model_loss:6.240498171912299 contrastive_loss:5.606798299153646 reg_loss:0.00023450411164150056 --------------
# train/ start...
# ---------------------------------49-th Precition:0.0100 Recall:0.0064 NDCG:0.0408---------------------------------
# val/cold_ start...
# ---------------------------------49-th Precition:0.0076 Recall:0.0076 NDCG:0.0102---------------------------------
# test/cold_ start...
# ---------------------------------49-th Precition:0.0087 Recall:0.0087 NDCG:0.0131---------------------------------
# Save best model as /content/drive/MyDrive/Capstone/Dataset/Office_Products/result/CLCRec/model_lr_1e-05_lrl_0.7_reg_0.01_num_neg_512_tmp_1.0.pt with recall 0.008685059601676984
# Start training epoch 50...
# Now, training start at epoch 50...
# 46080it [00:44, 1033.48it/s]
# ----------------- loss:5.601923264397515  model_loss:6.240492269727919 contrastive_loss:5.601694700453017 reg_loss:0.0002285887551907864 --------------
# train/ start...
# ---------------------------------50-th Precition:0.0102 Recall:0.0065 NDCG:0.0406---------------------------------
# val/cold_ start...
# ---------------------------------50-th Precition:0.0080 Recall:0.0080 NDCG:0.0103---------------------------------
# test/cold_ start...
# ---------------------------------50-th Precition:0.0086 Recall:0.0086 NDCG:0.0131---------------------------------
# Start training epoch 51...
# Now, training start at epoch 51...
# 46080it [00:44, 1034.69it/s]
# ----------------- loss:5.596945275200738  model_loss:6.240486717224121 contrastive_loss:5.596722348531087 reg_loss:0.00022293607439173178 --------------
# train/ start...
# ---------------------------------51-th Precition:0.0101 Recall:0.0063 NDCG:0.0397---------------------------------
# val/cold_ start...
# ---------------------------------51-th Precition:0.0084 Recall:0.0083 NDCG:0.0107---------------------------------
# test/cold_ start...
# ---------------------------------51-th Precition:0.0084 Recall:0.0084 NDCG:0.0133---------------------------------
# Start training epoch 52...
# Now, training start at epoch 52...
# 46080it [00:44, 1046.24it/s]
# ----------------- loss:5.592401006486681  model_loss:6.2404811435275604 contrastive_loss:5.592183589935303 reg_loss:0.00021740342231674328 --------------
# train/ start...
# ---------------------------------52-th Precition:0.0100 Recall:0.0063 NDCG:0.0393---------------------------------
# val/cold_ start...
# ---------------------------------52-th Precition:0.0083 Recall:0.0083 NDCG:0.0107---------------------------------
# test/cold_ start...
# ---------------------------------52-th Precition:0.0080 Recall:0.0080 NDCG:0.0132---------------------------------
# Start training epoch 53...
# Now, training start at epoch 53...
# 46080it [00:43, 1052.59it/s]
# ----------------- loss:5.587904665205214  model_loss:6.240476152631971 contrastive_loss:5.587692546844482 reg_loss:0.00021209339546557102 --------------
# train/ start...
# ---------------------------------53-th Precition:0.0100 Recall:0.0062 NDCG:0.0396---------------------------------
# val/cold_ start...
# ---------------------------------53-th Precition:0.0078 Recall:0.0078 NDCG:0.0105---------------------------------
# test/cold_ start...
# ---------------------------------53-th Precition:0.0082 Recall:0.0081 NDCG:0.0133---------------------------------
# Start training epoch 54...
# Now, training start at epoch 54...
# 46080it [00:43, 1048.59it/s]
# ----------------- loss:5.583398956722683  model_loss:6.240471246507433 contrastive_loss:5.5831920199924046 reg_loss:0.00020693320030760434 --------------
# train/ start...
# ---------------------------------54-th Precition:0.0100 Recall:0.0060 NDCG:0.0395---------------------------------
# val/cold_ start...
# ---------------------------------54-th Precition:0.0081 Recall:0.0081 NDCG:0.0105---------------------------------
# test/cold_ start...
# ---------------------------------54-th Precition:0.0085 Recall:0.0085 NDCG:0.0137---------------------------------
# Start training epoch 55...
# Now, training start at epoch 55...
# 46080it [00:44, 1047.27it/s]
# ----------------- loss:5.579449303944906  model_loss:6.2404664781358505 contrastive_loss:5.579247347513834 reg_loss:0.00020192864693753009 --------------
# train/ start...
# ---------------------------------55-th Precition:0.0102 Recall:0.0062 NDCG:0.0402---------------------------------
# val/cold_ start...
# ---------------------------------55-th Precition:0.0081 Recall:0.0081 NDCG:0.0105---------------------------------
# test/cold_ start...
# ---------------------------------55-th Precition:0.0088 Recall:0.0087 NDCG:0.0140---------------------------------
# Save best model as /content/drive/MyDrive/Capstone/Dataset/Office_Products/result/CLCRec/model_lr_1e-05_lrl_0.7_reg_0.01_num_neg_512_tmp_1.0.pt with recall 0.008719208723293816
# Start training epoch 56...
# Now, training start at epoch 56...
# 46080it [00:43, 1049.74it/s]
# ----------------- loss:5.575368319617377  model_loss:6.24046220779419 contrastive_loss:5.575171237521701 reg_loss:0.00019706759388403347 --------------
# train/ start...
# ---------------------------------56-th Precition:0.0104 Recall:0.0064 NDCG:0.0405---------------------------------
# val/cold_ start...
# ---------------------------------56-th Precition:0.0079 Recall:0.0078 NDCG:0.0105---------------------------------
# test/cold_ start...
# ---------------------------------56-th Precition:0.0090 Recall:0.0089 NDCG:0.0145---------------------------------
# Save best model as /content/drive/MyDrive/Capstone/Dataset/Office_Products/result/CLCRec/model_lr_1e-05_lrl_0.7_reg_0.01_num_neg_512_tmp_1.0.pt with recall 0.008910068782963984
# Start training epoch 57...
# Now, training start at epoch 57...
# 46080it [00:44, 1046.11it/s]
# ----------------- loss:5.571346028645833  model_loss:6.240457513597277 contrastive_loss:5.571153683132596 reg_loss:0.0001923575247120526 --------------
# train/ start...
# ---------------------------------57-th Precition:0.0105 Recall:0.0064 NDCG:0.0408---------------------------------
# val/cold_ start...
# ---------------------------------57-th Precition:0.0085 Recall:0.0084 NDCG:0.0108---------------------------------
# test/cold_ start...
# ---------------------------------57-th Precition:0.0090 Recall:0.0089 NDCG:0.0144---------------------------------
# Start training epoch 58...
# Now, training start at epoch 58...
# 46080it [00:44, 1044.03it/s]
# ----------------- loss:5.567629485660129  model_loss:6.240453052520752 contrastive_loss:5.56744171778361 reg_loss:0.00018776239303406329 --------------
# train/ start...
# ---------------------------------58-th Precition:0.0108 Recall:0.0065 NDCG:0.0413---------------------------------
# val/cold_ start...
# ---------------------------------58-th Precition:0.0085 Recall:0.0084 NDCG:0.0110---------------------------------
# test/cold_ start...
# ---------------------------------58-th Precition:0.0092 Recall:0.0091 NDCG:0.0149---------------------------------
# Save best model as /content/drive/MyDrive/Capstone/Dataset/Office_Products/result/CLCRec/model_lr_1e-05_lrl_0.7_reg_0.01_num_neg_512_tmp_1.0.pt with recall 0.009130830695739884
# Start training epoch 59...
# Now, training start at epoch 59...
# 46080it [00:43, 1047.60it/s]
# ----------------- loss:5.563831414116754  model_loss:6.240448655022515 contrastive_loss:5.563648075527615 reg_loss:0.00018334846083436988 --------------
# train/ start...
# ---------------------------------59-th Precition:0.0107 Recall:0.0064 NDCG:0.0403---------------------------------
# val/cold_ start...
# ---------------------------------59-th Precition:0.0084 Recall:0.0083 NDCG:0.0108---------------------------------
# test/cold_ start...
# ---------------------------------59-th Precition:0.0097 Recall:0.0096 NDCG:0.0153---------------------------------
# Save best model as /content/drive/MyDrive/Capstone/Dataset/Office_Products/result/CLCRec/model_lr_1e-05_lrl_0.7_reg_0.01_num_neg_512_tmp_1.0.pt with recall 0.009632157934593969
# Start training epoch 60...
# Now, training start at epoch 60...
# 46080it [00:43, 1048.25it/s]
# ----------------- loss:5.560373348659939  model_loss:6.240444755554199 contrastive_loss:5.560194312201606 reg_loss:0.00017902868470021834 --------------
# train/ start...
# ---------------------------------60-th Precition:0.0111 Recall:0.0066 NDCG:0.0411---------------------------------
# val/cold_ start...
# ---------------------------------60-th Precition:0.0088 Recall:0.0086 NDCG:0.0112---------------------------------
# test/cold_ start...
# ---------------------------------60-th Precition:0.0097 Recall:0.0095 NDCG:0.0155---------------------------------
# Start training epoch 61...
# Now, training start at epoch 61...
# 46080it [00:43, 1049.07it/s]
# ----------------- loss:5.557023429870606  model_loss:6.240440548790826 contrastive_loss:5.556848536597358 reg_loss:0.00017488336953748432 --------------
# train/ start...
# ---------------------------------61-th Precition:0.0113 Recall:0.0067 NDCG:0.0427---------------------------------
# val/cold_ start...
# ---------------------------------61-th Precition:0.0082 Recall:0.0080 NDCG:0.0108---------------------------------
# test/cold_ start...
# ---------------------------------61-th Precition:0.0101 Recall:0.0099 NDCG:0.0159---------------------------------
# Save best model as /content/drive/MyDrive/Capstone/Dataset/Office_Products/result/CLCRec/model_lr_1e-05_lrl_0.7_reg_0.01_num_neg_512_tmp_1.0.pt with recall 0.009948374505984991
# Start training epoch 62...
# Now, training start at epoch 62...
# 46080it [00:43, 1057.31it/s]
# ----------------- loss:5.553636741638184  model_loss:6.240436829460991 contrastive_loss:5.553465906778971 reg_loss:0.00017083592311893073 --------------
# train/ start...
# ---------------------------------62-th Precition:0.0119 Recall:0.0070 NDCG:0.0429---------------------------------
# val/cold_ start...
# ---------------------------------62-th Precition:0.0081 Recall:0.0080 NDCG:0.0113---------------------------------
# test/cold_ start...
# ---------------------------------62-th Precition:0.0100 Recall:0.0098 NDCG:0.0162---------------------------------
# Start training epoch 63...
# Now, training start at epoch 63...
# 46080it [00:43, 1048.69it/s]
# ----------------- loss:5.550459660424126  model_loss:6.240433216094971 contrastive_loss:5.550292788611518 reg_loss:0.00016686677635233436 --------------
# train/ start...
# ---------------------------------63-th Precition:0.0119 Recall:0.0069 NDCG:0.0427---------------------------------
# val/cold_ start...
# ---------------------------------63-th Precition:0.0082 Recall:0.0080 NDCG:0.0111---------------------------------
# test/cold_ start...
# ...
# Start training epoch 139...
# Now, training start at epoch 139...
# 46080it [00:43, 1048.52it/s]
# ----------------- loss:5.4531651708814834  model_loss:6.240309789445665 contrastive_loss:5.453130764431424 reg_loss:3.4379309605962284e-05 --------------
# train/ start...
# ---------------------------------139-th Precition:0.0475 Recall:0.0333 NDCG:0.1447---------------------------------
# val/cold_ start...
# ---------------------------------139-th Precition:0.0410 Recall:0.0408 NDCG:0.0510---------------------------------
# test/cold_ start...
# ---------------------------------139-th Precition:0.0481 Recall:0.0480 NDCG:0.0604---------------------------------
# Save best model as /content/drive/MyDrive/Capstone/Dataset/Office_Products/result/CLCRec/model_lr_1e-05_lrl_0.7_reg_0.01_num_neg_512_tmp_1.0.pt with recall 0.04796415171032713
# Start training epoch 140...
# Now, training start at epoch 140...
# 46080it [00:44, 1047.18it/s]
# ----------------- loss:5.452786297268338  model_loss:6.240309249030219 contrastive_loss:5.452752431233724 reg_loss:3.3877822392646015e-05 --------------
# train/ start...
# ---------------------------------140-th Precition:0.0481 Recall:0.0340 NDCG:0.1498---------------------------------
# val/cold_ start...
# ---------------------------------140-th Precition:0.0421 Recall:0.0419 NDCG:0.0511---------------------------------
# test/cold_ start...
# ---------------------------------140-th Precition:0.0468 Recall:0.0467 NDCG:0.0587---------------------------------
# Start training epoch 141...
# Now, training start at epoch 141...
# 46080it [00:43, 1049.11it/s]
# ----------------- loss:5.452595689561632  model_loss:6.24030876159668 contrastive_loss:5.452562310960558 reg_loss:3.338299656105745e-05 --------------
# train/ start...
# ---------------------------------141-th Precition:0.0473 Recall:0.0330 NDCG:0.1453---------------------------------
# val/cold_ start...
# ---------------------------------141-th Precition:0.0370 Recall:0.0367 NDCG:0.0469---------------------------------
# test/cold_ start...
# ---------------------------------141-th Precition:0.0482 Recall:0.0480 NDCG:0.0602---------------------------------
# Save best model as /content/drive/MyDrive/Capstone/Dataset/Office_Products/result/CLCRec/model_lr_1e-05_lrl_0.7_reg_0.01_num_neg_512_tmp_1.0.pt with recall 0.04800872816679004
# Start training epoch 142...
# Now, training start at epoch 142...
# 46080it [00:44, 1046.61it/s]
# ----------------- loss:5.452076890733507  model_loss:6.240308295355903 contrastive_loss:5.45204397837321 reg_loss:3.291148103825334e-05 --------------
# train/ start...
# ---------------------------------142-th Precition:0.0478 Recall:0.0338 NDCG:0.1481---------------------------------
# val/cold_ start...
# ---------------------------------142-th Precition:0.0384 Recall:0.0383 NDCG:0.0482---------------------------------
# test/cold_ start...
# ---------------------------------142-th Precition:0.0458 Recall:0.0456 NDCG:0.0582---------------------------------
# Start training epoch 143...
# Now, training start at epoch 143...
# 46080it [00:43, 1048.40it/s]
# ----------------- loss:5.451751073201497  model_loss:6.2403078291151255 contrastive_loss:5.451718627081977 reg_loss:3.246001102120822e-05 --------------
# train/ start...
# ---------------------------------143-th Precition:0.0454 Recall:0.0318 NDCG:0.1377---------------------------------
# val/cold_ start...
# ---------------------------------143-th Precition:0.0407 Recall:0.0404 NDCG:0.0498---------------------------------
# test/cold_ start...
# ---------------------------------143-th Precition:0.0461 Recall:0.0458 NDCG:0.0585---------------------------------
# Start training epoch 144...
# Now, training start at epoch 144...
# 46080it [00:43, 1051.83it/s]
# ----------------- loss:5.4518448723687065  model_loss:6.24030737347073 contrastive_loss:5.451812881893582 reg_loss:3.200966425033079e-05 --------------
# train/ start...
# ---------------------------------144-th Precition:0.0448 Recall:0.0312 NDCG:0.1373---------------------------------
# val/cold_ start...
# ---------------------------------144-th Precition:0.0369 Recall:0.0365 NDCG:0.0462---------------------------------
# test/cold_ start...
# ---------------------------------144-th Precition:0.0448 Recall:0.0444 NDCG:0.0562---------------------------------
# Start training epoch 145...
# Now, training start at epoch 145...
# 46080it [00:43, 1059.88it/s]
# ----------------- loss:5.451487816704644  model_loss:6.240306949615478 contrastive_loss:5.451456250084771 reg_loss:3.158582055928289e-05 --------------
# train/ start...
# ---------------------------------145-th Precition:0.0463 Recall:0.0328 NDCG:0.1467---------------------------------
# val/cold_ start...
# ---------------------------------145-th Precition:0.0398 Recall:0.0395 NDCG:0.0474---------------------------------
# test/cold_ start...
# ---------------------------------145-th Precition:0.0440 Recall:0.0437 NDCG:0.0560---------------------------------
# Start training epoch 146...
# Now, training start at epoch 146...
# 46080it [00:43, 1049.17it/s]
# ----------------- loss:5.4507454024420845  model_loss:6.240306536356608 contrastive_loss:5.450714249081082 reg_loss:3.1173630527013706e-05 --------------
# train/ start...
# ---------------------------------146-th Precition:0.0447 Recall:0.0317 NDCG:0.1417---------------------------------
# val/cold_ start...
# ---------------------------------146-th Precition:0.0380 Recall:0.0377 NDCG:0.0475---------------------------------
# test/cold_ start...
# ---------------------------------146-th Precition:0.0473 Recall:0.0470 NDCG:0.0572---------------------------------
# Start training epoch 147...
# Now, training start at epoch 147...
# 46080it [00:44, 1044.39it/s]
# ----------------- loss:5.450754239824083  model_loss:6.240306165483263 contrastive_loss:5.450723467932807 reg_loss:3.078341089551234e-05 --------------
# train/ start...
# ---------------------------------147-th Precition:0.0449 Recall:0.0318 NDCG:0.1441---------------------------------
# val/cold_ start...
# ---------------------------------147-th Precition:0.0369 Recall:0.0367 NDCG:0.0470---------------------------------
# test/cold_ start...
# ---------------------------------147-th Precition:0.0465 Recall:0.0464 NDCG:0.0568---------------------------------
# Start training epoch 148...
# Now, training start at epoch 148...
# 46080it [00:43, 1054.38it/s]
# ----------------- loss:5.450394545661078  model_loss:6.240305784013536 contrastive_loss:5.450364144643148 reg_loss:3.0390448915164192e-05 --------------
# train/ start...
# ---------------------------------148-th Precition:0.0448 Recall:0.0314 NDCG:0.1408---------------------------------
# val/cold_ start...
# ---------------------------------148-th Precition:0.0382 Recall:0.0380 NDCG:0.0479---------------------------------
# test/cold_ start...
# ---------------------------------148-th Precition:0.0447 Recall:0.0444 NDCG:0.0570---------------------------------
# Start training epoch 149...
# Now, training start at epoch 149...
# 46080it [00:44, 1046.91it/s]
# ----------------- loss:5.450106218126085  model_loss:6.240305423736572 contrastive_loss:5.450076177385118 reg_loss:3.0018328106962145e-05 --------------
# train/ start...
# ---------------------------------149-th Precition:0.0439 Recall:0.0308 NDCG:0.1398---------------------------------
# val/cold_ start...
# ---------------------------------149-th Precition:0.0359 Recall:0.0358 NDCG:0.0464---------------------------------
# test/cold_ start...
# ---------------------------------149-th Precition:0.0483 Recall:0.0482 NDCG:0.0579---------------------------------
# Save best model as /content/drive/MyDrive/Capstone/Dataset/Office_Products/result/CLCRec/model_lr_1e-05_lrl_0.7_reg_0.01_num_neg_512_tmp_1.0.pt with recall 0.048177171898342835
# Start training epoch 150...
# Now, training start at epoch 150...
# 46080it [00:43, 1053.97it/s]
# ----------------- loss:5.450038517846002  model_loss:6.240305021074083 contrastive_loss:5.450008879767524 reg_loss:2.9657982021389114e-05 --------------
# train/ start...
# ---------------------------------150-th Precition:0.0433 Recall:0.0308 NDCG:0.1398---------------------------------
# val/cold_ start...
# ---------------------------------150-th Precition:0.0403 Recall:0.0400 NDCG:0.0499---------------------------------
# test/cold_ start...
# ---------------------------------150-th Precition:0.0459 Recall:0.0457 NDCG:0.0560---------------------------------
# Start training epoch 151...
# Now, training start at epoch 151...
# 46080it [00:43, 1051.92it/s]
# ----------------- loss:5.449890285068088  model_loss:6.240304692586263 contrastive_loss:5.4498609754774305 reg_loss:2.9311007892829366e-05 --------------
# train/ start...
# ---------------------------------151-th Precition:0.0426 Recall:0.0303 NDCG:0.1365---------------------------------
# val/cold_ start...
# ---------------------------------151-th Precition:0.0397 Recall:0.0394 NDCG:0.0501---------------------------------
# test/cold_ start...
# ---------------------------------151-th Precition:0.0432 Recall:0.0429 NDCG:0.0547---------------------------------
# Start training epoch 152...
# Now, training start at epoch 152...
# 46080it [00:44, 1046.95it/s]
# ----------------- loss:5.4496064609951445  model_loss:6.240304448869494 contrastive_loss:5.449577405717638 reg_loss:2.8984568012270352e-05 --------------
# train/ start...
# ---------------------------------152-th Precition:0.0427 Recall:0.0305 NDCG:0.1387---------------------------------
# val/cold_ start...
# ---------------------------------152-th Precition:0.0386 Recall:0.0383 NDCG:0.0482---------------------------------
# test/cold_ start...
# ---------------------------------152-th Precition:0.0445 Recall:0.0442 NDCG:0.0582---------------------------------
# Start training epoch 153...
# Now, training start at epoch 153...
# 46080it [00:43, 1047.57it/s]
# ----------------- loss:5.449185201856825  model_loss:6.240303993225098 contrastive_loss:5.449156591627333 reg_loss:2.8659941623724686e-05 --------------
# train/ start...
# ---------------------------------153-th Precition:0.0413 Recall:0.0294 NDCG:0.1343---------------------------------
# val/cold_ start...
# ---------------------------------153-th Precition:0.0399 Recall:0.0397 NDCG:0.0492---------------------------------
# test/cold_ start...
# ---------------------------------153-th Precition:0.0444 Recall:0.0441 NDCG:0.0571---------------------------------
# Start training epoch 154...
# Now, training start at epoch 154...
# 46080it [00:43, 1059.81it/s]
# ----------------- loss:5.448960049947103  model_loss:6.240303738911947 contrastive_loss:5.448931694030762 reg_loss:2.834950108889542e-05 --------------
# train/ start...
# ---------------------------------154-th Precition:0.0416 Recall:0.0296 NDCG:0.1380---------------------------------
# val/cold_ start...
# ---------------------------------154-th Precition:0.0407 Recall:0.0404 NDCG:0.0515---------------------------------
# test/cold_ start...
# ---------------------------------154-th Precition:0.0422 Recall:0.0418 NDCG:0.0564---------------------------------
# Start training epoch 155...
# Now, training start at epoch 155...
# 46080it [00:44, 1040.45it/s]
# ----------------- loss:5.448613929748535  model_loss:6.240303505791558 contrastive_loss:5.4485858069525825 reg_loss:2.804883855181591e-05 --------------
# train/ start...
# ---------------------------------155-th Precition:0.0401 Recall:0.0283 NDCG:0.1258---------------------------------
# val/cold_ start...
# ---------------------------------155-th Precition:0.0410 Recall:0.0408 NDCG:0.0498---------------------------------
# test/cold_ start...
# ---------------------------------155-th Precition:0.0459 Recall:0.0456 NDCG:0.0575---------------------------------
# Start training epoch 156...
# Now, training start at epoch 156...
# 46080it [00:44, 1045.18it/s]
# ----------------- loss:5.448534764183892  model_loss:6.2403030607435435 contrastive_loss:5.448507086435954 reg_loss:2.7760213844077146e-05 --------------
# train/ start...
# ---------------------------------156-th Precition:0.0393 Recall:0.0279 NDCG:0.1285---------------------------------
# val/cold_ start...
# ---------------------------------156-th Precition:0.0379 Recall:0.0378 NDCG:0.0474---------------------------------
# test/cold_ start...
# ---------------------------------156-th Precition:0.0429 Recall:0.0428 NDCG:0.0552---------------------------------
# Start training epoch 157...
# Now, training start at epoch 157...
# 46080it [00:43, 1048.88it/s]
# ----------------- loss:5.448122066921658  model_loss:6.240302901797825 contrastive_loss:5.448094548119439 reg_loss:2.747615989291161e-05 --------------
# train/ start...
# ---------------------------------157-th Precition:0.0395 Recall:0.0279 NDCG:0.1279---------------------------------
# val/cold_ start...
# ---------------------------------157-th Precition:0.0393 Recall:0.0391 NDCG:0.0484---------------------------------
# test/cold_ start...
# ---------------------------------157-th Precition:0.0425 Recall:0.0423 NDCG:0.0546---------------------------------
# Start training epoch 158...
# Now, training start at epoch 158...
# 46080it [00:44, 1047.25it/s]
# ----------------- loss:5.4479659186469185  model_loss:6.240302562713623 contrastive_loss:5.447938738928901 reg_loss:2.7204297576746385e-05 --------------
# train/ start...
# ---------------------------------158-th Precition:0.0398 Recall:0.0285 NDCG:0.1278---------------------------------
# val/cold_ start...
# ---------------------------------158-th Precition:0.0366 Recall:0.0364 NDCG:0.0454---------------------------------
# test/cold_ start...
# ---------------------------------158-th Precition:0.0427 Recall:0.0426 NDCG:0.0553---------------------------------
# Start training epoch 159...
# Now, training start at epoch 159...
# 46080it [00:43, 1052.78it/s]
# ----------------- loss:5.447482268015544  model_loss:6.240302340189616 contrastive_loss:5.447455310821534 reg_loss:2.6934321956812508e-05 --------------
# train/ start...
# ---------------------------------159-th Precition:0.0395 Recall:0.0280 NDCG:0.1311---------------------------------
# val/cold_ start...
# ---------------------------------159-th Precition:0.0384 Recall:0.0381 NDCG:0.0475---------------------------------
# test/cold_ start...
# ---------------------------------159-th Precition:0.0455 Recall:0.0452 NDCG:0.0589---------------------------------
# Start training epoch 160...
# Now, training start at epoch 160...
# 46080it [00:44, 1041.80it/s]
# ----------------- loss:5.44773285124037  model_loss:6.240302085876465 contrastive_loss:5.447706148359511 reg_loss:2.6680299237745607e-05 --------------
# train/ start...
# ---------------------------------160-th Precition:0.0399 Recall:0.0288 NDCG:0.1301---------------------------------
# val/cold_ start...
# ---------------------------------160-th Precition:0.0385 Recall:0.0384 NDCG:0.0490---------------------------------
# test/cold_ start...
# ---------------------------------160-th Precition:0.0408 Recall:0.0407 NDCG:0.0509---------------------------------
# Start training epoch 161...
# Now, training start at epoch 161...
# 46080it [00:44, 1037.51it/s]
# ----------------- loss:5.447355482313368  model_loss:6.2403017891777885 contrastive_loss:5.447329076131185 reg_loss:2.6435216892019122e-05 --------------
# train/ start...
# ---------------------------------161-th Precition:0.0380 Recall:0.0267 NDCG:0.1242---------------------------------
# val/cold_ start...
# ---------------------------------161-th Precition:0.0400 Recall:0.0398 NDCG:0.0492---------------------------------
# test/cold_ start...
# ---------------------------------161-th Precition:0.0435 Recall:0.0432 NDCG:0.0562---------------------------------
# test/cold_ start...
# ----------------------------------1-th Precition:0.0483 Recall:0.0482 NDCG:0.0579---------------------------------
# Final Result:
# Test Cold Precition:0.0483 Recall:0.0482 NDCG:0.0579
# Finish training

# %%
DATASET = "Video_Games_Filtered"

# %%
# !rm -rf $SAVE_PATH/$DATASET/result/CLCRec_lrl07_temp1_hasv_hasoh

# %%
# !python3 main.py --seed $SEED \
                 --data-path $SAVE_PATH/$DATASET \
                 --result-path $SAVE_PATH/$DATASET/result/CLCRec_lrl07_temp1_hasv_hasoh \
                 --has-t \
                 --lr 0.00003 \
                 --lr-lambda 0.7 \
                 --reg-weight 0.01 \
                 --temp-value 1.0 \
                 --num-neg 512 \
                 --num-sample 0.5 \
                 --top-k 10 \
                 --batch-size 1024 \
                 --num-epoch 100 \
                 --early-stop 10 \
                 --step 1024 \
                 --has-oh \
                 --has-v
# Out:
# 2024-05-02 09:53:15.596833: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-02 09:53:15.596884: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-02 09:53:15.598255: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-05-02 09:53:15.605351: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-05-02 09:53:16.688768: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /content/drive/MyDrive/Capstone/Dataset/Video_Games_Filtered
# Data loading ...
# Data has been loaded.
# Start training epoch 0...
# Now, training start at epoch 0...
#   0% 0/240808 [00:00<?, ?it/s]/usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# 241664it [05:17, 760.09it/s]
# ----------------- loss:6.118869025828475  model_loss:6.240681066351422 contrastive_loss:6.118461794772391 reg_loss:0.00040722888747873415 --------------
# train/ start...
# ---------------------------------0-th Precition:0.0033 Recall:0.0028 NDCG:0.0108---------------------------------
# val/cold_ start...
# ---------------------------------0-th Precition:0.0047 Recall:0.0047 NDCG:0.0038---------------------------------
# test/cold_ start...
# ---------------------------------0-th Precition:0.0038 Recall:0.0038 NDCG:0.0029---------------------------------
# Save best model as /content/drive/MyDrive/Capstone/Dataset/Video_Games_Filtered/result/CLCRec_lrl07_temp1_hasv_hasoh/model_lr_3e-05_lrl_0.7_reg_0.01_num_neg_512_tmp_1.0.pt with recall 0.0037762518720420545
# Start training epoch 1...
# Now, training start at epoch 1...
# 241664it [05:17, 761.98it/s]
# ----------------- loss:5.7523048914085  model_loss:6.240463707406642 contrastive_loss:5.752114817247552 reg_loss:0.000190083030833255 --------------
# train/ start...
# ---------------------------------1-th Precition:0.0036 Recall:0.0030 NDCG:0.0108---------------------------------
# val/cold_ start...
# ---------------------------------1-th Precition:0.0063 Recall:0.0063 NDCG:0.0049---------------------------------
# test/cold_ start...
# ---------------------------------1-th Precition:0.0049 Recall:0.0049 NDCG:0.0042---------------------------------
# Save best model as /content/drive/MyDrive/Capstone/Dataset/Video_Games_Filtered/result/CLCRec_lrl07_temp1_hasv_hasoh/model_lr_3e-05_lrl_0.7_reg_0.01_num_neg_512_tmp_1.0.pt with recall 0.004862044661913115
# Start training epoch 2...
# Now, training start at epoch 2...
# 241664it [05:18, 758.76it/s]
# ----------------- loss:5.605947522793786  model_loss:6.240387245760125 contrastive_loss:5.605833823398008 reg_loss:0.00011370080435388105 --------------
# train/ start...
# ---------------------------------2-th Precition:0.0044 Recall:0.0037 NDCG:0.0136---------------------------------
# val/cold_ start...
# ---------------------------------2-th Precition:0.0076 Recall:0.0076 NDCG:0.0060---------------------------------
# test/cold_ start...
# ---------------------------------2-th Precition:0.0063 Recall:0.0063 NDCG:0.0053---------------------------------
# Save best model as /content/drive/MyDrive/Capstone/Dataset/Video_Games_Filtered/result/CLCRec_lrl07_temp1_hasv_hasoh/model_lr_3e-05_lrl_0.7_reg_0.01_num_neg_512_tmp_1.0.pt with recall 0.006269329855533517
# Start training epoch 3...
# Now, training start at epoch 3...
# 241664it [05:18, 759.03it/s]
# ----------------- loss:5.5450737941063055  model_loss:6.240354069208695 contrastive_loss:5.544994150177907 reg_loss:7.965674074327226e-05 --------------
# train/ start...
# ---------------------------------3-th Precition:0.0081 Recall:0.0066 NDCG:0.0244---------------------------------
# val/cold_ start...
# ---------------------------------3-th Precition:0.0097 Recall:0.0096 NDCG:0.0092---------------------------------
# test/cold_ start...
# ---------------------------------3-th Precition:0.0089 Recall:0.0088 NDCG:0.0086---------------------------------
# Save best model as /content/drive/MyDrive/Capstone/Dataset/Video_Games_Filtered/result/CLCRec_lrl07_temp1_hasv_hasoh/model_lr_3e-05_lrl_0.7_reg_0.01_num_neg_512_tmp_1.0.pt with recall 0.008845992030147088
# Start training epoch 4...
# Now, training start at epoch 4...
# 241664it [05:20, 755.05it/s]
# ----------------- loss:5.517566012123884  model_loss:6.240335904945762 contrastive_loss:5.517505298226567 reg_loss:6.072259928537355e-05 --------------
# train/ start...
# ---------------------------------4-th Precition:0.0179 Recall:0.0156 NDCG:0.0533---------------------------------
# val/cold_ start...
# ---------------------------------4-th Precition:0.0163 Recall:0.0162 NDCG:0.0159---------------------------------
# test/cold_ start...
# ---------------------------------4-th Precition:0.0181 Recall:0.0180 NDCG:0.0162---------------------------------
# Save best model as /content/drive/MyDrive/Capstone/Dataset/Video_Games_Filtered/result/CLCRec_lrl07_temp1_hasv_hasoh/model_lr_3e-05_lrl_0.7_reg_0.01_num_neg_512_tmp_1.0.pt with recall 0.01801707555499759
# Start training epoch 5...
# Now, training start at epoch 5...
# 241664it [05:20, 753.78it/s]
# ----------------- loss:5.501695158117909  model_loss:6.240324040590706 contrastive_loss:5.501646500522807 reg_loss:4.865405605676765e-05 --------------
# train/ start...
# ---------------------------------5-th Precition:0.0278 Recall:0.0253 NDCG:0.0827---------------------------------
# val/cold_ start...
# ---------------------------------5-th Precition:0.0201 Recall:0.0200 NDCG:0.0187---------------------------------
# test/cold_ start...
# ---------------------------------5-th Precition:0.0228 Recall:0.0227 NDCG:0.0204---------------------------------
# Save best model as /content/drive/MyDrive/Capstone/Dataset/Video_Games_Filtered/result/CLCRec_lrl07_temp1_hasv_hasoh/model_lr_3e-05_lrl_0.7_reg_0.01_num_neg_512_tmp_1.0.pt with recall 0.02273078791678235
# Start training epoch 6...
# Now, training start at epoch 6...
# 241664it [05:20, 754.39it/s]
# ----------------- loss:5.490197820178533  model_loss:6.240316728414116 contrastive_loss:5.490156474760023 reg_loss:4.134077407489728e-05 --------------
# train/ start...
# ---------------------------------6-th Precition:0.0304 Recall:0.0279 NDCG:0.0914---------------------------------
# val/cold_ start...
# ---------------------------------6-th Precition:0.0209 Recall:0.0208 NDCG:0.0178---------------------------------
# test/cold_ start...
# ---------------------------------6-th Precition:0.0230 Recall:0.0229 NDCG:0.0231---------------------------------
# Save best model as /content/drive/MyDrive/Capstone/Dataset/Video_Games_Filtered/result/CLCRec_lrl07_temp1_hasv_hasoh/model_lr_3e-05_lrl_0.7_reg_0.01_num_neg_512_tmp_1.0.pt with recall 0.02289532410869168
# Start training epoch 7...
# Now, training start at epoch 7...
# 241664it [05:19, 756.08it/s]
# ----------------- loss:5.479963607707266  model_loss:6.240312873306921 contrastive_loss:5.479926119416447 reg_loss:3.749790669074065e-05 --------------
# train/ start...
# ---------------------------------7-th Precition:0.0290 Recall:0.0266 NDCG:0.0867---------------------------------
# val/cold_ start...
# ---------------------------------7-th Precition:0.0191 Recall:0.0191 NDCG:0.0146---------------------------------
# test/cold_ start...
# ---------------------------------7-th Precition:0.0206 Recall:0.0205 NDCG:0.0212---------------------------------
# Start training epoch 8...
# Now, training start at epoch 8...
# 241664it [05:19, 755.46it/s]
# ----------------- loss:5.471165210513745  model_loss:6.240311014450203 contrastive_loss:5.471129581079644 reg_loss:3.559724965748886e-05 --------------
# train/ start...
# ---------------------------------8-th Precition:0.0252 Recall:0.0231 NDCG:0.0751---------------------------------
# val/cold_ start...
# ---------------------------------8-th Precition:0.0142 Recall:0.0142 NDCG:0.0102---------------------------------
# test/cold_ start...
# ---------------------------------8-th Precition:0.0178 Recall:0.0177 NDCG:0.0185---------------------------------
# Start training epoch 9...
# Now, training start at epoch 9...
# 241664it [05:18, 758.23it/s]
# ----------------- loss:5.464060534865169  model_loss:6.240309753660428 contrastive_loss:5.464026164200346 reg_loss:3.438977586545476e-05 --------------
# train/ start...
# ---------------------------------9-th Precition:0.0205 Recall:0.0186 NDCG:0.0640---------------------------------
# val/cold_ start...
# ---------------------------------9-th Precition:0.0131 Recall:0.0131 NDCG:0.0084---------------------------------
# test/cold_ start...
# ---------------------------------9-th Precition:0.0175 Recall:0.0174 NDCG:0.0169---------------------------------
# Start training epoch 10...
# Now, training start at epoch 10...
# 241664it [05:20, 753.53it/s]
# ----------------- loss:5.458574594077417  model_loss:6.24030892525689 contrastive_loss:5.458541051816132 reg_loss:3.346151306224352e-05 --------------
# train/ start...
# ---------------------------------10-th Precition:0.0181 Recall:0.0162 NDCG:0.0569---------------------------------
# val/cold_ start...
# ---------------------------------10-th Precition:0.0124 Recall:0.0124 NDCG:0.0091---------------------------------
# test/cold_ start...
# ---------------------------------10-th Precition:0.0163 Recall:0.0162 NDCG:0.0170---------------------------------
# Start training epoch 11...
# Now, training start at epoch 11...
# 241664it [05:20, 753.55it/s]
# ----------------- loss:5.454603544736313  model_loss:6.240308066545906 contrastive_loss:5.4545708632065075 reg_loss:3.2725325412283677e-05 --------------
# train/ start...
# ---------------------------------11-th Precition:0.0158 Recall:0.0139 NDCG:0.0511---------------------------------
# val/cold_ start...
# ---------------------------------11-th Precition:0.0097 Recall:0.0096 NDCG:0.0068---------------------------------
# test/cold_ start...
# ---------------------------------11-th Precition:0.0155 Recall:0.0155 NDCG:0.0147---------------------------------
# Start training epoch 12...
# Now, training start at epoch 12...
# 241664it [05:18, 759.34it/s]
# ----------------- loss:5.4520586547205  model_loss:6.240307688713074 contrastive_loss:5.452026349003032 reg_loss:3.232025049991365e-05 --------------
# train/ start...
# ---------------------------------12-th Precition:0.0134 Recall:0.0118 NDCG:0.0447---------------------------------
# val/cold_ start...
# ---------------------------------12-th Precition:0.0101 Recall:0.0101 NDCG:0.0068---------------------------------
# test/cold_ start...
# ---------------------------------12-th Precition:0.0132 Recall:0.0131 NDCG:0.0132---------------------------------
# Start training epoch 13...
# Now, training start at epoch 13...
# 241664it [05:18, 759.27it/s]
# ----------------- loss:5.449904773194911  model_loss:6.240307450294495 contrastive_loss:5.449872705896022 reg_loss:3.207901967070322e-05 --------------
# train/ start...
# ---------------------------------13-th Precition:0.0124 Recall:0.0107 NDCG:0.0425---------------------------------
# val/cold_ start...
# ---------------------------------13-th Precition:0.0095 Recall:0.0095 NDCG:0.0068---------------------------------
# test/cold_ start...
# ---------------------------------13-th Precition:0.0135 Recall:0.0135 NDCG:0.0131---------------------------------
# Start training epoch 14...
# Now, training start at epoch 14...
# 241664it [05:19, 756.84it/s]
# ----------------- loss:5.448009355593536  model_loss:6.24030737957712 contrastive_loss:5.447977361032518 reg_loss:3.1885873903451344e-05 --------------
# train/ start...
# ---------------------------------14-th Precition:0.0111 Recall:0.0096 NDCG:0.0389---------------------------------
# val/cold_ start...
# ---------------------------------14-th Precition:0.0079 Recall:0.0079 NDCG:0.0055---------------------------------
# test/cold_ start...
# ---------------------------------14-th Precition:0.0143 Recall:0.0142 NDCG:0.0129---------------------------------
# Start training epoch 15...
# Now, training start at epoch 15...
# 241664it [05:18, 758.88it/s]
# ----------------- loss:5.44686133174573  model_loss:6.240307017908258 contrastive_loss:5.446829696833077 reg_loss:3.1662669012587424e-05 --------------
# train/ start...
# ---------------------------------15-th Precition:0.0112 Recall:0.0095 NDCG:0.0380---------------------------------
# val/cold_ start...
# ---------------------------------15-th Precition:0.0092 Recall:0.0092 NDCG:0.0065---------------------------------
# test/cold_ start...
# ---------------------------------15-th Precition:0.0124 Recall:0.0124 NDCG:0.0123---------------------------------
# Start training epoch 16...
# Now, training start at epoch 16...
# 241664it [05:18, 758.66it/s]
# ----------------- loss:5.445895768828311  model_loss:6.240306939108897 contrastive_loss:5.445864212715019 reg_loss:3.1545417017295516e-05 --------------
# train/ start...
# ---------------------------------16-th Precition:0.0108 Recall:0.0092 NDCG:0.0372---------------------------------
# val/cold_ start...
# ---------------------------------16-th Precition:0.0090 Recall:0.0090 NDCG:0.0062---------------------------------
# test/cold_ start...
# ---------------------------------16-th Precition:0.0114 Recall:0.0113 NDCG:0.0111---------------------------------
# Start training epoch 17...
# Now, training start at epoch 17...
# 241664it [05:17, 761.55it/s]
# ----------------- loss:5.4450692221269765  model_loss:6.240306906780954 contrastive_loss:5.445037698341628 reg_loss:3.145682856453369e-05 --------------
# train/ start...
# ---------------------------------17-th Precition:0.0099 Recall:0.0084 NDCG:0.0352---------------------------------
# val/cold_ start...
# ---------------------------------17-th Precition:0.0090 Recall:0.0089 NDCG:0.0060---------------------------------
# test/cold_ start...
# ---------------------------------17-th Precition:0.0111 Recall:0.0111 NDCG:0.0104---------------------------------
# Start training epoch 18...
# Now, training start at epoch 18...
# 241664it [05:16, 762.82it/s]
# ----------------- loss:5.4441517429836725  model_loss:6.240306799694643 contrastive_loss:5.444120330325628 reg_loss:3.140185216872882e-05 --------------
# train/ start...
# ---------------------------------18-th Precition:0.0105 Recall:0.0090 NDCG:0.0369---------------------------------
# val/cold_ start...
# ---------------------------------18-th Precition:0.0084 Recall:0.0084 NDCG:0.0058---------------------------------
# test/cold_ start...
# ---------------------------------18-th Precition:0.0107 Recall:0.0107 NDCG:0.0099---------------------------------
# test/cold_ start...
# ----------------------------------1-th Precition:0.0230 Recall:0.0229 NDCG:0.0231---------------------------------
# Final Result:
# Test Cold Precition:0.0230 Recall:0.0229 NDCG:0.0231
# Finish training

# %%
DATASET = "Office_Products_Filtered"

# %%
# !rm -rf $SAVE_PATH/$DATASET/result/CLCRec_lrl07_temp1_hasv_hasoh

# %%
# !python3 main.py --seed $SEED \
                 --data-path $SAVE_PATH/$DATASET \
                 --result-path $SAVE_PATH/$DATASET/result/CLCRec_lrl07_temp1_hasv_hasoh \
                 --has-t \
                 --lr 0.00002 \
                 --lr-lambda 0.7 \
                 --reg-weight 0.01 \
                 --temp-value 1.0 \
                 --num-neg 512 \
                 --num-sample 0.5 \
                 --top-k 10 \
                 --batch-size 1024 \
                 --num-epoch 1000 \
                 --early-stop 10 \
                 --step 1024 \
                 --has-oh \
                 --has-v
# Out:
# 2024-05-02 11:44:59.274771: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-02 11:44:59.274817: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-02 11:44:59.276258: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-05-02 11:44:59.283728: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-05-02 11:45:00.431172: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /content/drive/MyDrive/Capstone/Dataset/Office_Products_Filtered
# Data loading ...
# Data has been loaded.
# Start training epoch 0...
# Now, training start at epoch 0...
#   0% 0/116328 [00:00<?, ?it/s]/usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# 116736it [02:45, 705.73it/s]
# ----------------- loss:6.228963287253129  model_loss:6.240866284621389 contrastive_loss:6.22837027332239 reg_loss:0.000593017292997326 --------------
# train/ start...
# ---------------------------------0-th Precition:0.0009 Recall:0.0008 NDCG:0.0028---------------------------------
# val/cold_ start...
# ---------------------------------0-th Precition:0.0032 Recall:0.0032 NDCG:0.0020---------------------------------
# test/cold_ start...
# ---------------------------------0-th Precition:0.0024 Recall:0.0024 NDCG:0.0019---------------------------------
# Save best model as /content/drive/MyDrive/Capstone/Dataset/Office_Products_Filtered/result/CLCRec_lrl07_temp1_hasv_hasoh/model_lr_2e-05_lrl_0.7_reg_0.01_num_neg_512_tmp_1.0.pt with recall 0.0024208223435359544
# Start training epoch 1...
# Now, training start at epoch 1...
# 116736it [02:36, 744.99it/s]
# ----------------- loss:6.164079657772131  model_loss:6.2407299426564 contrastive_loss:6.1636299334074325 reg_loss:0.0004497341606908952 --------------
# train/ start...
# ---------------------------------1-th Precition:0.0019 Recall:0.0016 NDCG:0.0073---------------------------------
# val/cold_ start...
# ---------------------------------1-th Precition:0.0045 Recall:0.0045 NDCG:0.0035---------------------------------
# test/cold_ start...
# ---------------------------------1-th Precition:0.0043 Recall:0.0043 NDCG:0.0035---------------------------------
# Save best model as /content/drive/MyDrive/Capstone/Dataset/Office_Products_Filtered/result/CLCRec_lrl07_temp1_hasv_hasoh/model_lr_2e-05_lrl_0.7_reg_0.01_num_neg_512_tmp_1.0.pt with recall 0.004298033081845875
# Start training epoch 2...
# Now, training start at epoch 2...
# 116736it [02:38, 738.48it/s]
# ----------------- loss:5.9826384343599015  model_loss:6.240626460627506 contrastive_loss:5.982288962916324 reg_loss:0.00034946904787303587 --------------
# train/ start...
# ---------------------------------2-th Precition:0.0027 Recall:0.0023 NDCG:0.0094---------------------------------
# val/cold_ start...
# ---------------------------------2-th Precition:0.0041 Recall:0.0041 NDCG:0.0032---------------------------------
# test/cold_ start...
# ---------------------------------2-th Precition:0.0042 Recall:0.0042 NDCG:0.0035---------------------------------
# Start training epoch 3...
# Now, training start at epoch 3...
# 116736it [02:36, 744.33it/s]
# ----------------- loss:5.872709424872148  model_loss:6.24055450422722 contrastive_loss:5.87242949636359 reg_loss:0.0002799271720792412 --------------
# train/ start...
# ---------------------------------3-th Precition:0.0032 Recall:0.0027 NDCG:0.0099---------------------------------
# val/cold_ start...
# ---------------------------------3-th Precition:0.0042 Recall:0.0042 NDCG:0.0033---------------------------------
# test/cold_ start...
# ---------------------------------3-th Precition:0.0044 Recall:0.0044 NDCG:0.0039---------------------------------
# Save best model as /content/drive/MyDrive/Capstone/Dataset/Office_Products_Filtered/result/CLCRec_lrl07_temp1_hasv_hasoh/model_lr_2e-05_lrl_0.7_reg_0.01_num_neg_512_tmp_1.0.pt with recall 0.004428675363089274
# Start training epoch 4...
# Now, training start at epoch 4...
# 116736it [02:35, 752.94it/s]
# ----------------- loss:5.795636474040517  model_loss:6.240503047641955 contrastive_loss:5.795407445807206 reg_loss:0.00022905434595661957 --------------
# train/ start...
# ---------------------------------4-th Precition:0.0033 Recall:0.0028 NDCG:0.0103---------------------------------
# val/cold_ start...
# ---------------------------------4-th Precition:0.0042 Recall:0.0042 NDCG:0.0033---------------------------------
# test/cold_ start...
# ---------------------------------4-th Precition:0.0045 Recall:0.0045 NDCG:0.0040---------------------------------
# Save best model as /content/drive/MyDrive/Capstone/Dataset/Office_Products_Filtered/result/CLCRec_lrl07_temp1_hasv_hasoh/model_lr_2e-05_lrl_0.7_reg_0.01_num_neg_512_tmp_1.0.pt with recall 0.004491291650480143
# Start training epoch 5...
# Now, training start at epoch 5...
# 116736it [02:41, 721.48it/s]
# ----------------- loss:5.735120639466403  model_loss:6.240464076661227 contrastive_loss:5.734929791668005 reg_loss:0.00019084417931081955 --------------
# train/ start...
# ---------------------------------5-th Precition:0.0033 Recall:0.0028 NDCG:0.0103---------------------------------
# val/cold_ start...
# ---------------------------------5-th Precition:0.0048 Recall:0.0048 NDCG:0.0037---------------------------------
# test/cold_ start...
# ---------------------------------5-th Precition:0.0049 Recall:0.0049 NDCG:0.0041---------------------------------
# Save best model as /content/drive/MyDrive/Capstone/Dataset/Office_Products_Filtered/result/CLCRec_lrl07_temp1_hasv_hasoh/model_lr_2e-05_lrl_0.7_reg_0.01_num_neg_512_tmp_1.0.pt with recall 0.004917678750332249
# Start training epoch 6...
# Now, training start at epoch 6...
# 116736it [02:38, 734.42it/s]
# ----------------- loss:5.686574898268047  model_loss:6.240434763724344 contrastive_loss:5.686413170998557 reg_loss:0.00016172052455020318 --------------
# train/ start...
# ---------------------------------6-th Precition:0.0032 Recall:0.0027 NDCG:0.0106---------------------------------
# val/cold_ start...
# ---------------------------------6-th Precition:0.0054 Recall:0.0054 NDCG:0.0043---------------------------------
# test/cold_ start...
# ---------------------------------6-th Precition:0.0046 Recall:0.0046 NDCG:0.0039---------------------------------
# Start training epoch 7...
# Now, training start at epoch 7...
# 116736it [02:36, 744.69it/s]
# ----------------- loss:5.6477330609371785  model_loss:6.240412189249406 contrastive_loss:5.647593895594279 reg_loss:0.00013918206113566268 --------------
# train/ start...
# ---------------------------------7-th Precition:0.0035 Recall:0.0029 NDCG:0.0113---------------------------------
# val/cold_ start...
# ---------------------------------7-th Precition:0.0058 Recall:0.0058 NDCG:0.0046---------------------------------
# test/cold_ start...
# ---------------------------------7-th Precition:0.0045 Recall:0.0045 NDCG:0.0037---------------------------------
# Start training epoch 8...
# Now, training start at epoch 8...
# 116736it [02:35, 751.73it/s]
# ----------------- loss:5.616773952517593  model_loss:6.240394684306362 contrastive_loss:5.616652480342932 reg_loss:0.0001214643228817486 --------------
# train/ start...
# ---------------------------------8-th Precition:0.0035 Recall:0.0028 NDCG:0.0116---------------------------------
# val/cold_ start...
# ---------------------------------8-th Precition:0.0061 Recall:0.0061 NDCG:0.0051---------------------------------
# test/cold_ start...
# ---------------------------------8-th Precition:0.0045 Recall:0.0045 NDCG:0.0035---------------------------------
# Start training epoch 9...
# Now, training start at epoch 9...
# 116736it [02:36, 744.85it/s]
# ----------------- loss:5.592183543924699  model_loss:6.240380671986363 contrastive_loss:5.592076301574707 reg_loss:0.00010726363555142215 --------------
# train/ start...
# ---------------------------------9-th Precition:0.0039 Recall:0.0030 NDCG:0.0128---------------------------------
# val/cold_ start...
# ---------------------------------9-th Precition:0.0058 Recall:0.0058 NDCG:0.0049---------------------------------
# test/cold_ start...
# ---------------------------------9-th Precition:0.0046 Recall:0.0045 NDCG:0.0037---------------------------------
# Start training epoch 10...
# Now, training start at epoch 10...
# 116736it [02:36, 745.15it/s]
# ----------------- loss:5.572479181122362  model_loss:6.240369399388631 contrastive_loss:5.572383520895975 reg_loss:9.567304183739205e-05 --------------
# train/ start...
# ---------------------------------10-th Precition:0.0043 Recall:0.0033 NDCG:0.0138---------------------------------
# val/cold_ start...
# ---------------------------------10-th Precition:0.0059 Recall:0.0058 NDCG:0.0052---------------------------------
# test/cold_ start...
# ---------------------------------10-th Precition:0.0046 Recall:0.0046 NDCG:0.0039---------------------------------
# Start training epoch 11...
# Now, training start at epoch 11...
# 116736it [02:35, 749.81it/s]
# ----------------- loss:5.556761164414255  model_loss:6.240360126160739 contrastive_loss:5.556675124586675 reg_loss:8.602789341494555e-05 --------------
# train/ start...
# ---------------------------------11-th Precition:0.0051 Recall:0.0037 NDCG:0.0161---------------------------------
# val/cold_ start...
# ---------------------------------11-th Precition:0.0067 Recall:0.0067 NDCG:0.0059---------------------------------
# test/cold_ start...
# ---------------------------------11-th Precition:0.0057 Recall:0.0057 NDCG:0.0050---------------------------------
# Save best model as /content/drive/MyDrive/Capstone/Dataset/Office_Products_Filtered/result/CLCRec_lrl07_temp1_hasv_hasoh/model_lr_2e-05_lrl_0.7_reg_0.01_num_neg_512_tmp_1.0.pt with recall 0.005653867386370606
# Start training epoch 12...
# Now, training start at epoch 12...
# 116736it [02:36, 747.73it/s]
# ----------------- loss:5.543674510821962  model_loss:6.240352216519807 contrastive_loss:5.543596669247276 reg_loss:7.783748470389758e-05 --------------
# train/ start...
# ---------------------------------12-th Precition:0.0065 Recall:0.0047 NDCG:0.0201---------------------------------
# val/cold_ start...
# ---------------------------------12-th Precition:0.0078 Recall:0.0078 NDCG:0.0068---------------------------------
# test/cold_ start...
# ---------------------------------12-th Precition:0.0055 Recall:0.0055 NDCG:0.0054---------------------------------
# Start training epoch 13...
# Now, training start at epoch 13...
# 116736it [02:37, 741.02it/s]
# ----------------- loss:5.532577464455052  model_loss:6.240345302381013 contrastive_loss:5.532506687599316 reg_loss:7.078775110003015e-05 --------------
# train/ start...
# ---------------------------------13-th Precition:0.0086 Recall:0.0065 NDCG:0.0260---------------------------------
# val/cold_ start...
# ---------------------------------13-th Precition:0.0097 Recall:0.0097 NDCG:0.0094---------------------------------
# test/cold_ start...
# ---------------------------------13-th Precition:0.0081 Recall:0.0081 NDCG:0.0081---------------------------------
# Save best model as /content/drive/MyDrive/Capstone/Dataset/Office_Products_Filtered/result/CLCRec_lrl07_temp1_hasv_hasoh/model_lr_2e-05_lrl_0.7_reg_0.01_num_neg_512_tmp_1.0.pt with recall 0.0081075980058796
# Start training epoch 14...
# Now, training start at epoch 14...
# 116736it [02:36, 747.86it/s]
# ----------------- loss:5.5232280220901755  model_loss:6.2403394715827805 contrastive_loss:5.523163414838021 reg_loss:6.462219282280115e-05 --------------
# train/ start...
# ---------------------------------14-th Precition:0.0107 Recall:0.0085 NDCG:0.0322---------------------------------
# val/cold_ start...
# ---------------------------------14-th Precition:0.0109 Recall:0.0109 NDCG:0.0104---------------------------------
# test/cold_ start...
# ---------------------------------14-th Precition:0.0103 Recall:0.0102 NDCG:0.0098---------------------------------
# Save best model as /content/drive/MyDrive/Capstone/Dataset/Office_Products_Filtered/result/CLCRec_lrl07_temp1_hasv_hasoh/model_lr_2e-05_lrl_0.7_reg_0.01_num_neg_512_tmp_1.0.pt with recall 0.010230862417959884
# Start training epoch 15...
# Now, training start at epoch 15...
# 116736it [02:35, 752.99it/s]
# ----------------- loss:5.514490449637697  model_loss:6.24033444387871 contrastive_loss:5.514431275819478 reg_loss:5.917537256257339e-05 --------------
# train/ start...
# ---------------------------------15-th Precition:0.0141 Recall:0.0116 NDCG:0.0426---------------------------------
# val/cold_ start...
# ---------------------------------15-th Precition:0.0129 Recall:0.0129 NDCG:0.0124---------------------------------
# test/cold_ start...
# ---------------------------------15-th Precition:0.0134 Recall:0.0134 NDCG:0.0130---------------------------------
# Save best model as /content/drive/MyDrive/Capstone/Dataset/Office_Products_Filtered/result/CLCRec_lrl07_temp1_hasv_hasoh/model_lr_2e-05_lrl_0.7_reg_0.01_num_neg_512_tmp_1.0.pt with recall 0.013353626121981637
# Start training epoch 16...
# Now, training start at epoch 16...
# 116736it [02:38, 738.32it/s]
# ----------------- loss:5.506835494125099  model_loss:6.240329742431641 contrastive_loss:5.506781134689064 reg_loss:5.43559033343499e-05 --------------
# train/ start...
# ---------------------------------16-th Precition:0.0176 Recall:0.0148 NDCG:0.0530---------------------------------
# val/cold_ start...
# ---------------------------------16-th Precition:0.0132 Recall:0.0131 NDCG:0.0126---------------------------------
# test/cold_ start...
# ---------------------------------16-th Precition:0.0157 Recall:0.0157 NDCG:0.0147---------------------------------
# Save best model as /content/drive/MyDrive/Capstone/Dataset/Office_Products_Filtered/result/CLCRec_lrl07_temp1_hasv_hasoh/model_lr_2e-05_lrl_0.7_reg_0.01_num_neg_512_tmp_1.0.pt with recall 0.01567051394767152
# Start training epoch 17...
# Now, training start at epoch 17...
# 116736it [02:40, 728.67it/s]
# ----------------- loss:5.500024076093707  model_loss:6.240325492725038 contrastive_loss:5.499973966364275 reg_loss:5.0102657105685866e-05 --------------
# train/ start...
# ---------------------------------17-th Precition:0.0215 Recall:0.0183 NDCG:0.0626---------------------------------
# val/cold_ start...
# ---------------------------------17-th Precition:0.0146 Recall:0.0145 NDCG:0.0138---------------------------------
# test/cold_ start...
# ---------------------------------17-th Precition:0.0183 Recall:0.0182 NDCG:0.0170---------------------------------
# Save best model as /content/drive/MyDrive/Capstone/Dataset/Office_Products_Filtered/result/CLCRec_lrl07_temp1_hasv_hasoh/model_lr_2e-05_lrl_0.7_reg_0.01_num_neg_512_tmp_1.0.pt with recall 0.01821703742324181
# Start training epoch 18...
# Now, training start at epoch 18...
# 116736it [02:40, 726.60it/s]
# ----------------- loss:5.493727817870023  model_loss:6.240321761683414 contrastive_loss:5.493681439182215 reg_loss:4.637777911148876e-05 --------------
# train/ start...
# ---------------------------------18-th Precition:0.0227 Recall:0.0193 NDCG:0.0665---------------------------------
# val/cold_ start...
# ---------------------------------18-th Precition:0.0166 Recall:0.0166 NDCG:0.0158---------------------------------
# test/cold_ start...
# ---------------------------------18-th Precition:0.0198 Recall:0.0197 NDCG:0.0179---------------------------------
# Save best model as /content/drive/MyDrive/Capstone/Dataset/Office_Products_Filtered/result/CLCRec_lrl07_temp1_hasv_hasoh/model_lr_2e-05_lrl_0.7_reg_0.01_num_neg_512_tmp_1.0.pt with recall 0.01971671880431005
# Start training epoch 19...
# Now, training start at epoch 19...
# 116736it [02:40, 726.82it/s]
# ----------------- loss:5.488583870101393  model_loss:6.240318582769026 contrastive_loss:5.488540670327973 reg_loss:4.319409922652739e-05 --------------
# train/ start...
# ---------------------------------19-th Precition:0.0240 Recall:0.0203 NDCG:0.0662---------------------------------
# val/cold_ start...
# ---------------------------------19-th Precition:0.0178 Recall:0.0177 NDCG:0.0154---------------------------------
# test/cold_ start...
# ---------------------------------19-th Precition:0.0216 Recall:0.0215 NDCG:0.0185---------------------------------
# Save best model as /content/drive/MyDrive/Capstone/Dataset/Office_Products_Filtered/result/CLCRec_lrl07_temp1_hasv_hasoh/model_lr_2e-05_lrl_0.7_reg_0.01_num_neg_512_tmp_1.0.pt with recall 0.02154332535934082
# Start training epoch 20...
# Now, training start at epoch 20...
# 116736it [02:40, 727.27it/s]
# ----------------- loss:5.483996884864673  model_loss:6.240315901605706 contrastive_loss:5.4839563662545725 reg_loss:4.0511025106656905e-05 --------------
# train/ start...
# ---------------------------------20-th Precition:0.0235 Recall:0.0197 NDCG:0.0644---------------------------------
# val/cold_ start...
# ---------------------------------20-th Precition:0.0166 Recall:0.0166 NDCG:0.0153---------------------------------
# test/cold_ start...
# ---------------------------------20-th Precition:0.0195 Recall:0.0195 NDCG:0.0157---------------------------------
# Start training epoch 21...
# Now, training start at epoch 21...
# 116736it [02:38, 735.46it/s]
# ----------------- loss:5.479740326864677  model_loss:6.24031364708616 contrastive_loss:5.479702062774122 reg_loss:3.825617874865298e-05 --------------
# train/ start...
# ---------------------------------21-th Precition:0.0241 Recall:0.0203 NDCG:0.0658---------------------------------
# val/cold_ start...
# ---------------------------------21-th Precition:0.0183 Recall:0.0182 NDCG:0.0171---------------------------------
# test/cold_ start...
# ---------------------------------21-th Precition:0.0200 Recall:0.0199 NDCG:0.0154---------------------------------
# Start training epoch 22...
# Now, training start at epoch 22...
# 116736it [02:38, 738.19it/s]
# ----------------- loss:5.476362332963107  model_loss:6.240311760651438 contrastive_loss:5.476325955307274 reg_loss:3.637989347656625e-05 --------------
# train/ start...
# ---------------------------------22-th Precition:0.0228 Recall:0.0190 NDCG:0.0625---------------------------------
# val/cold_ start...
# ---------------------------------22-th Precition:0.0192 Recall:0.0191 NDCG:0.0175---------------------------------
# test/cold_ start...
# ---------------------------------22-th Precition:0.0190 Recall:0.0190 NDCG:0.0153---------------------------------
# Start training epoch 23...
# Now, training start at epoch 23...
# 116736it [02:36, 745.02it/s]
# ----------------- loss:5.473290564721091  model_loss:6.240310208839283 contrastive_loss:5.4732557388774135 reg_loss:3.482025848617859e-05 --------------
# train/ start...
# ---------------------------------23-th Precition:0.0209 Recall:0.0172 NDCG:0.0572---------------------------------
# val/cold_ start...
# ---------------------------------23-th Precition:0.0191 Recall:0.0191 NDCG:0.0171---------------------------------
# test/cold_ start...
# ---------------------------------23-th Precition:0.0182 Recall:0.0181 NDCG:0.0150---------------------------------
# Start training epoch 24...
# Now, training start at epoch 24...
# 116736it [02:36, 746.56it/s]
# ----------------- loss:5.470249058907492  model_loss:6.240308912176835 contrastive_loss:5.4702155297262625 reg_loss:3.353151987539604e-05 --------------
# train/ start...
# ---------------------------------24-th Precition:0.0212 Recall:0.0176 NDCG:0.0589---------------------------------
# val/cold_ start...
# ---------------------------------24-th Precition:0.0173 Recall:0.0172 NDCG:0.0153---------------------------------
# test/cold_ start...
# ---------------------------------24-th Precition:0.0171 Recall:0.0171 NDCG:0.0133---------------------------------
# Start training epoch 25...
# Now, training start at epoch 25...
# 116736it [02:38, 738.30it/s]
# ----------------- loss:5.468102346386826  model_loss:6.240307833019056 contrastive_loss:5.468069896363375 reg_loss:3.2473673312332517e-05 --------------
# train/ start...
# ---------------------------------25-th Precition:0.0206 Recall:0.0169 NDCG:0.0562---------------------------------
# val/cold_ start...
# ---------------------------------25-th Precition:0.0186 Recall:0.0185 NDCG:0.0165---------------------------------
# test/cold_ start...
# ---------------------------------25-th Precition:0.0142 Recall:0.0142 NDCG:0.0115---------------------------------
# Start training epoch 26...
# Now, training start at epoch 26...
# 116736it [02:37, 743.02it/s]
# ----------------- loss:5.465934782697444  model_loss:6.240307013193767 contrastive_loss:5.4659031524992825 reg_loss:3.159248026668936e-05 --------------
# train/ start...
# ---------------------------------26-th Precition:0.0200 Recall:0.0164 NDCG:0.0561---------------------------------
# val/cold_ start...
# ---------------------------------26-th Precition:0.0204 Recall:0.0203 NDCG:0.0176---------------------------------
# test/cold_ start...
# ---------------------------------26-th Precition:0.0162 Recall:0.0162 NDCG:0.0134---------------------------------
# Start training epoch 27...
# Now, training start at epoch 27...
# 116736it [02:35, 751.99it/s]
# ----------------- loss:5.463987388108906  model_loss:6.240306231013515 contrastive_loss:5.4639565400909955 reg_loss:3.08798013672155e-05 --------------
# train/ start...
# ---------------------------------27-th Precition:0.0198 Recall:0.0162 NDCG:0.0541---------------------------------
# val/cold_ start...
# ---------------------------------27-th Precition:0.0177 Recall:0.0176 NDCG:0.0167---------------------------------
# test/cold_ start...
# ---------------------------------27-th Precition:0.0165 Recall:0.0165 NDCG:0.0130---------------------------------
# Start training epoch 28...
# Now, training start at epoch 28...
# 116736it [02:36, 746.48it/s]
# ----------------- loss:5.462121879845335  model_loss:6.2403055994134204 contrastive_loss:5.46209166342752 reg_loss:3.0237844089641474e-05 --------------
# train/ start...
# ---------------------------------28-th Precition:0.0196 Recall:0.0161 NDCG:0.0556---------------------------------
# val/cold_ start...
# ---------------------------------28-th Precition:0.0203 Recall:0.0202 NDCG:0.0181---------------------------------
# test/cold_ start...
# ---------------------------------28-th Precition:0.0177 Recall:0.0176 NDCG:0.0139---------------------------------
# Start training epoch 29...
# Now, training start at epoch 29...
# 116736it [02:35, 750.71it/s]
# ----------------- loss:5.46100145892093  model_loss:6.240305093296787 contrastive_loss:5.460971748619749 reg_loss:2.971363594776465e-05 --------------
# train/ start...
# ---------------------------------29-th Precition:0.0202 Recall:0.0167 NDCG:0.0563---------------------------------
# val/cold_ start...
# ---------------------------------29-th Precition:0.0161 Recall:0.0160 NDCG:0.0157---------------------------------
# test/cold_ start...
# ---------------------------------29-th Precition:0.0156 Recall:0.0155 NDCG:0.0128---------------------------------
# Start training epoch 30...
# Now, training start at epoch 30...
# 116736it [02:35, 750.84it/s]
# ----------------- loss:5.459646668350487  model_loss:6.240304633190758 contrastive_loss:5.459617418155336 reg_loss:2.9284933046718626e-05 --------------
# train/ start...
# ---------------------------------30-th Precition:0.0204 Recall:0.0170 NDCG:0.0585---------------------------------
# val/cold_ start...
# ---------------------------------30-th Precition:0.0216 Recall:0.0216 NDCG:0.0181---------------------------------
# test/cold_ start...
# ---------------------------------30-th Precition:0.0158 Recall:0.0158 NDCG:0.0126---------------------------------
# Start training epoch 31...
# Now, training start at epoch 31...
# 116736it [02:36, 746.81it/s]
# ----------------- loss:5.458297005870886  model_loss:6.240304281837062 contrastive_loss:5.458268107029429 reg_loss:2.8929391574868197e-05 --------------
# train/ start...
# ---------------------------------31-th Precition:0.0204 Recall:0.0170 NDCG:0.0588---------------------------------
# val/cold_ start...
# ---------------------------------31-th Precition:0.0200 Recall:0.0200 NDCG:0.0172---------------------------------
# test/cold_ start...
# ---------------------------------31-th Precition:0.0168 Recall:0.0168 NDCG:0.0132---------------------------------
# test/cold_ start...
# ----------------------------------1-th Precition:0.0216 Recall:0.0215 NDCG:0.0185---------------------------------
# Final Result:
# Test Cold Precition:0.0216 Recall:0.0215 NDCG:0.0185
# Finish training

# %%
from google.colab import runtime
runtime.unassign()
